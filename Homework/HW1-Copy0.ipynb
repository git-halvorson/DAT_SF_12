# %% [markdown]
# #HW 1
#
# ##In this homework, you will be using concepts from the SQL lecture and APIs to explroe a dataset and make some basic queries.

# %%
# Import Pandas, Numpy, Matplotlib, and Sqlite3
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sqlite3
#from seaborn import plt

# This enables inline Plots
# %matplotlib inline

# Limit rows displayed in notebook
pd.set_option('display.max_rows', 10)
pd.set_option('display.precision', 2)

# %% [markdown]
# #### 1. Connect to the SF.Gov API and pull data from the 311 Table
# https://data.sfgov.org/City-Infrastructure/Case-Data-from-San-Francisco-311-SF311-/vw6y-z8j6
#
# * 311 data contains over 1.1 Million rows in total. For this exercise, we are only looking to pull the FIRST 1000 rows
#
# Note: To get more data than 1000 rows, you may need to sign up for an app token to avoid throttling limits
# http://dev.socrata.com/foundry/#/data.sfgov.org/vw6y-z8j6
#
# We don't need this for the exercise, but something to keep in mind as you work with external APIs

# %%
# This will get you the first 1000 rows to get started with the rest of the questions

import json
import urllib
import requests

url = "https://data.sfgov.org/resource/vw6y-z8j6.json"
data = json.load(urllib.urlopen(url))
data = filter(None,data)
data
# Out:
# [{u'address': u'Intersection of GOLDEN GATE AVE and JONES ST',
#   u'case_id': u'4427994',
#   u'category': u'Litter Receptacles',
#   u'neighborhood': u'Downtown/Civic Center',
#   u'opened': u'2015-01-26T05:11:59',
#   u'point': {u'latitude': u'37.7820729735132',
#    u'longitude': u'-122.412220705195',
#    u'needs_recoding': False},
#   u'request_details': u'N/A',
#   u'request_type': u'Damaged_City_Can',
#   u'responsible_agency': u'DPW Ops Queue',
#   u'source': u'Integrated Agency',
#   u'status': u'Open',
#   u'supervisor_district': u'6',
#   u'updated': u'2015-01-26T14:23:54'},
#  {u'address': u'Intersection of 32ND AVE and FULTON ST',
#   u'case_id': u'4427993',
#   u'category': u'Street and Sidewalk Cleaning',
#   u'closed': u'2015-01-26T12:15:28',
#   u'neighborhood': u'Outer Richmond',
#   u'opened': u'2015-01-26T04:59:10',
#   u'point': {u'latitude': u'37.7722274014997',
#    u'longitude': u'-122.491688146133',
#    u'needs_recoding': False},
#   u'request_details': u'Other Loose Garbage',
#   u'request_type': u'General Cleaning',
#   u'responsible_agency': u'Recology_Abandoned',
#   u'source': u'Voice In',
#   u'status': u'Closed',
#   u'supervisor_district': u'1',
#   u'updated': u'2015-01-26T12:15:28'},
#  {u'address': u'1020 CONNECTICUT ST, SAN FRANCISCO, CA, 94107',
#   u'case_id': u'4427981',
#   u'category': u'SFHA Requests',
#   u'neighborhood': u'Potrero Hill',
#   u'opened': u'2015-01-26T02:10:13',
#   u'point': {u'latitude': u'37.753133662641',
#    u'longitude': u'-122.397502153879',
#    u'needs_recoding': False},
#   u'request_details': u'Electricians',
#   u'request_type': u'SFHA Priority - Urgent',
#   u'responsible_agency': u'311 HA SR Queue',
#   u'source': u'Voice In',
#   u'status': u'Open',
#   u'supervisor_district': u'10',
#   u'updated': u'2015-01-26T02:15:39'},
#  {u'address': u'Intersection of BACHE ST and CRESCENT AVE',
#   u'case_id': u'4427977',
#   u'category': u'Street and Sidewalk Cleaning',
#   u'closed': u'2015-01-26T11:28:55',
#   u'neighborhood': u'Bernal Heights',
#   u'opened': u'2015-01-26T02:03:09',
#   u'point': {u'latitude': u'37.7349209780181',
#    u'longitude': u'-122.417478825042',
#    u'needs_recoding': False},
#   u'request_details': u'Refrigerator',
#   u'request_type': u'Bulky Items',
#   u'responsible_agency': u'Recology_Abandoned',
#   u'source': u'Voice In',
#   u'status': u'Closed',
#   u'supervisor_district': u'9',
#   u'updated': u'2015-01-26T11:28:55'},
#  {u'address': u'3830 23RD ST, SAN FRANCISCO, CA, 94114',
#   u'case_id': u'4427972',
#   u'category': u'Abandoned Vehicle',
#   u'neighborhood': u'Noe Valley',
#   u'opened': u'2015-01-26T01:08:08',
#   u'point': {u'latitude': u'37.753377557888',
#    u'longitude': u'-122.428354453071',
#    u'needs_recoding': False},
#   u'request_details': u'Silver - BMW -  - 6xtv099',
#   u'request_type': u'Abandoned Vehicle - Car4door',
#   u'responsible_agency': u'DPT Abandoned Vehicles Work Queue',
#   u'source': u'Web Self Service',
#   u'status': u'Open',
#   u'supervisor_district': u'8',
#   u'updated': u'2015-01-26T11:52:17'},
#  {u'address': u'1263 LEAVENWORTH ST, SAN FRANCISCO, CA, 94109',
#   u'case_id': u'4427971',
#   u'category': u'Residential Building Request',
#   u'closed': u'2015-01-26T13:32:48',
#   u'neighborhood': u'Nob Hill',
#   u'opened': u'2015-01-26T01:03:50',
#   u'point': {u'latitude': u'37.792822837477',
#    u'longitude': u'-122.416209164382',
#    u'needs_recoding': False},
#   u'request_details': u'Noise_Caused_by_Building_Systems',
#   u'request_type': u'Building - Noise_Caused_by_Building_Systems',
#   u'responsible_agency': u'DPH - Environmental Health - G',
#   u'source': u'Web Self Service',
#   u'status': u'Closed',
#   u'supervisor_district': u'3',
#   u'updated': u'2015-01-26T13:32:48'},
#  {u'address': u'34 CHURCH ST, SAN FRANCISCO, CA, 94117',
#   u'case_id': u'4427947',
#   u'category': u'Street and Sidewalk Cleaning',
#   u'closed': u'2015-01-26T09:02:28',
#   u'neighborhood': u'Western Addition',
#   u'opened': u'2015-01-26T00:07:45',
#   u'point': {u'latitude': u'37.770040029536',
#    u'longitude': u'-122.429245619276',
#    u'needs_recoding': False},
#   u'request_details': u'Other Loose Garbage',
#   u'request_type': u'General Cleaning',
#   u'responsible_agency': u'DPW Ops Queue',
#   u'source': u'Open311',
#   u'status': u'Closed',
#   u'supervisor_district': u'8',
#   u'updated': u'2015-01-26T09:02:28'},
#  {u'address': u'201 SPEAR ST, SAN FRANCISCO, CA, 94105',
#   u'case_id': u'4427946',
#   u'category': u'Sewer Issues',
#   u'closed': u'2015-01-26T07:57:25',
#   u'media_url': {u'url': u'http://mobile311.sfgov.org/media/san_francisco/report/photos/54c5f5c5df865a0667cd699e/photo_20150126_000325.jpg'},
#   u'neighborhood': u'Financial District',
#   u'opened': u'2015-01-26T00:07:41',
#   u'point': {u'latitude': u'37.79105274081',
#    u'longitude': u'-122.391970196514',
#    u'needs_recoding': False},
#   u'request_details': u'On_street',
#   u'request_type': u'Flooding',
#   u'responsible_agency': u'PUC Sewer Ops',
#   u'source': u'Open311',
#   u'status': u'Closed',
#   u'supervisor_district': u'6',
#   u'updated': u'2015-01-26T07:57:25'},
#  {u'address': u'200 BROAD ST, SAN FRANCISCO, CA, 94112',
#   u'case_id': u'4427937',
#   u'category': u'Graffiti Public Property',
#   u'closed': u'2015-01-26T06:58:56',
#   u'media_url': {u'url': u'http://mobile311.sfgov.org/media/san_francisco/report/photos/54c54965df865a0667cd6295/report.jpg'},
#   u'neighborhood': u'Ocean View',
#   u'opened': u'2015-01-25T23:55:06',
#   u'point': {u'latitude': u'37.713294981518',
#    u'longitude': u'-122.459164585663',
#    u'needs_recoding': False},
#   u'request_details': u'Other_enter_additional_details_below - Offensive',
#   u'request_type': u'Offensive Graffiti on Public Property',
#   u'responsible_agency': u'DPW Ops Queue',
#   u'source': u'Open311',
#   u'status': u'Closed',
#   u'supervisor_district': u'11',
#   u'updated': u'2015-01-26T06:58:56'},
#  {u'address': u'Intersection of 36TH AVE and QUINTARA ST',
#   u'case_id': u'4427902',
#   u'category': u'Street and Sidewalk Cleaning',
#   u'closed': u'2015-01-26T12:49:45',
#   u'media_url': {u'url': u'http://mobile311.sfgov.org/media/san_francisco/report/photos/54c5e6cbdf865a0667cd6858/report.jpg'},
#   u'neighborhood': u'Outer Sunset',
#   u'opened': u'2015-01-25T23:03:48',
#   u'point': {u'latitude': u'37.7478410269863',
#    u'longitude': u'-122.494297065332',
#    u'needs_recoding': False},
#   u'request_details': u'Furniture',
#   u'request_type': u'Bulky Items',
#   u'responsible_agency': u'Recology_Abandoned',
#   u'source': u'Open311',
#   u'status': u'Closed',
#   u'supervisor_district': u'4',
#   u'updated': u'2015-01-26T12:49:45'},
#  {u'address': u'2183 15TH ST, SAN FRANCISCO, CA, 94114',
#   u'case_id': u'4427881',
#   u'category': u'Tree Maintenance',
#   u'media_url': {u'url': u'http://mobile311.sfgov.org/media/san_francisco/report/photos/54c5db66df865a0667cd6845/report.jpg'},
#   u'neighborhood': u'Castro/Upper Market',
#   u'opened': u'2015-01-25T22:15:09',
#   u'point': {u'latitude': u'37.765797615955',
#    u'longitude': u'-122.432495313177',
#    u'needs_recoding': False},
#   u'request_details': u'Pruning_request',
#   u'request_type': u'Trees - Overgrown_Tree',
#   u'responsible_agency': u'DPW Ops Queue',
#   u'source': u'Open311',
#   u'status': u'Open',
#   u'supervisor_district': u'8',
#   u'updated': u'2015-01-26T06:54:01'},
#  {u'address': u'2153 15TH ST, SAN FRANCISCO, CA, 94114',
#   u'case_id': u'4427880',
#   u'category': u'Tree Maintenance',
#   u'media_url': {u'url': u'http://mobile311.sfgov.org/media/san_francisco/report/photos/54c5dae5df865a0667cd6839/report.jpg'},
#   u'neighborhood': u'Castro/Upper Market',
#   u'opened': u'2015-01-25T22:13:04',
#   u'point': {u'latitude': u'37.76567757',
#    u'longitude': u'-122.432243512',
#    u'needs_recoding': False},
#   u'request_details': u'Pruning_request',
#   u'request_type': u'Trees - Overgrown_Tree',
#   u'responsible_agency': u'DPW Ops Queue',
#   u'source': u'Open311',
#   u'status': u'Open',
#   u'supervisor_district': u'8',
#   u'updated': u'2015-01-25T22:13:04'},
#  {u'address': u'BUILDING 491 31ST AVENUE, , SAN FRANCISCO, CA, 94121',
#   u'case_id': u'4427875',
#   u'category': u'SFHA Requests',
#   u'neighborhood': u'Outer Richmond',
#   u'opened': u'2015-01-25T22:07:32',
#   u'point': {u'latitude': u'37.780120169',
#    u'longitude': u'-122.4915142',
#    u'needs_recoding': False},
#   u'request_details': u'Steam Fitters',
#   u'request_type': u'SFHA Priority - Urgent',
#   u'responsible_agency': u'311 HA SR Queue',
#   u'source': u'Voice In',
#   u'status': u'Open',
#   u'supervisor_district': u'1',
#   u'updated': u'2015-01-25T22:09:55'},
#  {u'address': u'1060 ASHBURY ST, SAN FRANCISCO, CA, 94117',
#   u'case_id': u'4427871',
#   u'category': u'Streetlights',
#   u'neighborhood': u'Haight Ashbury',
#   u'opened': u'2015-01-25T22:05:12',
#   u'point': {u'latitude': u'37.763384526736',
#    u'longitude': u'-122.446389724001',
#    u'needs_recoding': False},
#   u'request_details': u'Light_Burnt_Out on Metal Pole',
#   u'request_type': u'Streetlight - Light_Burnt_Out',
#   u'responsible_agency': u'PUC Streetlights Queue',
#   u'source': u'Voice In',
#   u'status': u'Open',
#   u'supervisor_district': u'8',
#   u'updated': u'2015-01-26T16:01:44'},
#  {u'address': u'292 DOUGLASS ST, SAN FRANCISCO, CA, 94114',
#   u'case_id': u'4427864',
#   u'category': u'Street and Sidewalk Cleaning',
#   u'closed': u'2015-01-26T02:09:00',
#   u'neighborhood': u'Castro/Upper Market',
#   u'opened': u'2015-01-25T22:02:35',
#   u'point': {u'latitude': u'37.759137805447',
#    u'longitude': u'-122.439249362448',
#    u'needs_recoding': False},
#   u'request_details': u'Other Loose Garbage',
#   u'request_type': u'General Cleaning',
#   u'responsible_agency': u'DPW Ops Queue',
#   u'source': u'Open311',
#   u'status': u'Closed',
#   u'supervisor_district': u'8',
#   u'updated': u'2015-01-26T02:09:00'},
#  {u'address': u'Intersection of OFARRELL ST and VAN NESS AVE',
#   u'case_id': u'4427858',
#   u'category': u'Street Defects',
#   u'media_url': {u'url': u'https://311crm-prod.ad.sfgov.org/attachments/viewCaseNoteAttachments.jsp?caseid=4427858'},
#   u'neighborhood': u'Western Addition',
#   u'opened': u'2015-01-25T22:00:27',
#   u'point': {u'latitude': u'37.7847534032066',
#    u'longitude': u'-122.421193138923',
#    u'needs_recoding': False},
#   u'request_details': u'Pavement_Defect',
#   u'request_type': u'Pavement_Defect',
#   u'responsible_agency': u'DPW BSSR Queue',
#   u'source': u'Web Self Service',
#   u'status': u'Open',
#   u'supervisor_district': u'6',
#   u'updated': u'2015-01-26T01:08:17'},
#  {u'address': u'2296 28TH AVE, SAN FRANCISCO, CA, 94116',
#   u'case_id': u'4427850',
#   u'category': u'Street and Sidewalk Cleaning',
#   u'closed': u'2015-01-26T09:25:33',
#   u'media_url': {u'url': u'http://mobile311.sfgov.org/media/san_francisco/report/photos/54c5d593df865a0667cd681d/photo_20150125_214831.jpg'},
#   u'neighborhood': u'Parkside',
#   u'opened': u'2015-01-25T21:50:16',
#   u'point': {u'latitude': u'37.744646357352',
#    u'longitude': u'-122.485317711131',
#    u'needs_recoding': False},
#   u'request_details': u'Furniture',
#   u'request_type': u'Bulky Items',
#   u'responsible_agency': u'Recology_Abandoned',
#   u'source': u'Open311',
#   u'status': u'Closed',
#   u'supervisor_district': u'4',
#   u'updated': u'2015-01-26T09:25:33'},
#  {u'address': u'Intersection of 48TH AVE and IRVING ST',
#   u'case_id': u'4427848',
#   u'category': u'Street and Sidewalk Cleaning',
#   u'closed': u'2015-01-26T12:29:09',
#   u'media_url': {u'url': u'http://mobile311.sfgov.org/media/san_francisco/report/photos/54c5d572df865a0667cd6813/report.jpg'},
#   u'neighborhood': u'Outer Sunset',
#   u'opened': u'2015-01-25T21:49:45',
#   u'point': {u'latitude': u'37.7621903064739',
#    u'longitude': u'-122.508198661991',
#    u'needs_recoding': False},
#   u'request_details': u'Furniture',
#   u'request_type': u'Bulky Items',
#   u'responsible_agency': u'Recology_Abandoned',
#   u'source': u'Open311',
#   u'status': u'Closed',
#   u'supervisor_district': u'4',
#   u'updated': u'2015-01-26T12:29:09'},
#  {u'address': u'438 BROADWAY, SAN FRANCISCO, CA, 94133',
#   u'case_id': u'4427838',
#   u'category': u'Street and Sidewalk Cleaning',
#   u'closed': u'2015-01-26T02:30:00',
#   u'neighborhood': u'North Beach',
#   u'opened': u'2015-01-25T21:45:01',
#   u'point': {u'latitude': u'37.798284752772',
#    u'longitude': u'-122.404608684533',
#    u'needs_recoding': False},
#   u'request_details': u'Paper Spill',
#   u'request_type': u'General Cleaning',
#   u'responsible_agency': u'DPW Ops Queue',
#   u'source': u'Web Self Service',
#   u'status': u'Closed',
#   u'supervisor_district': u'3',
#   u'updated': u'2015-01-26T02:30:00'},
#  {u'address': u'450 BROADWAY, SAN FRANCISCO, CA, 94133',
#   u'case_id': u'4427829',
#   u'category': u'Street and Sidewalk Cleaning',
#   u'closed': u'2015-01-26T02:00:00',
#   u'neighborhood': u'North Beach',
#   u'opened': u'2015-01-25T21:39:31',
#   u'point': {u'latitude': u'37.798269699656',
#    u'longitude': u'-122.40472759914',
#    u'needs_recoding': False},
#   u'request_details': u'Paper Spill',
#   u'request_type': u'General Cleaning',
#   u'responsible_agency': u'DPW Ops Queue',
#   u'source': u'Web Self Service',
#   u'status': u'Closed',
#   u'supervisor_district': u'3',
#   u'updated': u'2015-01-26T02:00:00'},
#  {u'address': u'Intersection of 18TH ST and CHURCH ST',
#   u'case_id': u'4427828',
#   u'category': u'Sewer Issues',
#   u'closed': u'2015-01-26T13:29:08',
#   u'media_url': {u'url': u'https://311crm-prod.ad.sfgov.org/attachments/viewCaseNoteAttachments.jsp?caseid=4427828'},
#   u'neighborhood': u'Castro/Upper Market',
#   u'opened': u'2015-01-25T21:38:04',
#   u'point': {u'latitude': u'37.7612895823341',
#    u'longitude': u'-122.428354118317',
#    u'needs_recoding': False},
#   u'request_details': u'Sewage_back_up Outofsewervent4inch',
#   u'request_type': u'Sewage_back_up',
#   u'responsible_agency': u'PUC Sewer Ops',
#   u'source': u'Web Self Service',
#   u'status': u'Closed',
#   u'supervisor_district': u'8',
#   u'updated': u'2015-01-26T13:29:08'},
#  {u'address': u'Intersection of ILLINOIS ST and MARIN ST',
#   u'case_id': u'4427819',
#   u'category': u'Streetlights',
#   u'neighborhood': u'Bayview',
#   u'opened': u'2015-01-25T21:32:20',
#   u'point': {u'latitude': u'37.7490658564126',
#    u'longitude': u'-122.386427837761',
#    u'needs_recoding': False},
#   u'request_details': u'Light_Flickering_On_Off on Metal Pole',
#   u'request_type': u'Streetlight - Light_Flickering_On_Off',
#   u'responsible_agency': u'PG and E - Streetlights Queue',
#   u'source': u'Voice In',
#   u'status': u'Open',
#   u'supervisor_district': u'10',
#   u'updated': u'2015-01-26T14:28:51'},
#  {u'address': u'37 BACHE ST, SAN FRANCISCO, CA, 94110',
#   u'case_id': u'4427816',
#   u'category': u'Sewer Issues',
#   u'closed': u'2015-01-26T21:53:14',
#   u'neighborhood': u'Bernal Heights',
#   u'opened': u'2015-01-25T21:28:07',
#   u'point': {u'latitude': u'37.734403914343',
#    u'longitude': u'-122.417420412366',
#    u'needs_recoding': False},
#   u'request_details': u'Other',
#   u'request_type': u'Water_leak',
#   u'responsible_agency': u'PUC - Water - G',
#   u'source': u'Voice In',
#   u'status': u'Closed',
#   u'supervisor_district': u'9',
#   u'updated': u'2015-01-26T21:53:14'},
#  {u'address': u'Intersection of DORIC ALY and JACKSON ST',
#   u'case_id': u'4427815',
#   u'category': u'Street Defects',
#   u'neighborhood': u'Nob Hill',
#   u'opened': u'2015-01-25T21:28:01',
#   u'point': {u'latitude': u'37.7954674918066',
#    u'longitude': u'-122.41108165533',
#    u'needs_recoding': False},
#   u'request_details': u'Pavement_Defect',
#   u'request_type': u'Pavement_Defect',
#   u'responsible_agency': u'DPW BSSR Queue',
#   u'source': u'Web Self Service',
#   u'status': u'Open',
#   u'supervisor_district': u'3',
#   u'updated': u'2015-01-25T21:53:51'},
#  {u'address': u'8 DORIC ALY, SAN FRANCISCO, CA, 94108',
#   u'case_id': u'4427783',
#   u'category': u'Street Defects',
#   u'closed': u'2015-01-26T06:24:08',
#   u'neighborhood': u'Nob Hill',
#   u'opened': u'2015-01-25T21:09:53',
#   u'point': {u'latitude': u'37.795102943441',
#    u'longitude': u'-122.411196369492',
#    u'needs_recoding': False},
#   u'request_details': u'Pavement_Defect',
#   u'request_type': u'Pavement_Defect',
#   u'responsible_agency': u'DPW BSSR Queue',
#   u'source': u'Web Self Service',
#   u'status': u'Closed',
#   u'supervisor_district': u'3',
#   u'updated': u'2015-01-26T06:24:08'},
#  {u'address': u'Intersection of EUGENIA AVE and GATES ST',
#   u'case_id': u'4427768',
#   u'category': u'Sign Repair',
#   u'neighborhood': u'Bernal Heights',
#   u'opened': u'2015-01-25T20:57:12',
#   u'point': {u'latitude': u'37.7403168899555',
#    u'longitude': u'-122.413923786407',
#    u'needs_recoding': False},
#   u'request_details': u'Stop - Defaced; support - Other',
#   u'request_type': u'Sign - Defaced',
#   u'responsible_agency': u'DPT SignShop Survey Tech - Dave McLaughlin Queue',
#   u'source': u'Voice In',
#   u'status': u'Open',
#   u'supervisor_district': u'9',
#   u'updated': u'2015-01-26T10:10:56'},
#  {u'address': u'Lower Great Highway, , SAN FRANCISCO, CA, 94122',
#   u'case_id': u'4427764',
#   u'category': u'Rec and Park Requests',
#   u'neighborhood': u'Outer Sunset',
#   u'opened': u'2015-01-25T20:54:43',
#   u'point': {u'latitude': u'37.749280731',
#    u'longitude': u'-122.5081756',
#    u'needs_recoding': False},
#   u'request_details': u'Trash_Dumping',
#   u'request_type': u'Park - Neighborhood_Services_Area',
#   u'responsible_agency': u'RPD NSA Queue',
#   u'source': u'Web Self Service',
#   u'status': u'Open',
#   u'supervisor_district': u'4',
#   u'updated': u'2015-01-25T20:54:43'},
#  {u'address': u'Intersection of 17TH ST and PROSPER ST',
#   u'case_id': u'4427762',
#   u'category': u'Street and Sidewalk Cleaning',
#   u'closed': u'2015-01-26T09:20:50',
#   u'neighborhood': u'Castro/Upper Market',
#   u'opened': u'2015-01-25T20:52:57',
#   u'point': {u'latitude': u'37.7627030998165',
#    u'longitude': u'-122.431544705694',
#    u'needs_recoding': False},
#   u'request_details': u'Furniture',
#   u'request_type': u'Bulky Items',
#   u'responsible_agency': u'Recology_Abandoned',
#   u'source': u'Voice In',
#   u'status': u'Closed',
#   u'supervisor_district': u'8',
#   u'updated': u'2015-01-26T09:20:50'},
#  {u'address': u'Intersection of 14TH ST and CHURCH ST',
#   u'case_id': u'4427755',
#   u'category': u'Damaged Property',
#   u'closed': u'2015-01-26T10:25:35',
#   u'neighborhood': u'Castro/Upper Market',
#   u'opened': u'2015-01-25T20:50:09',
#   u'point': {u'latitude': u'37.7677290345204',
#    u'longitude': u'-122.428968713134',
#    u'needs_recoding': False},
#   u'request_details': u'Transit_Shelter_Platform_Hazardous',
#   u'request_type': u'Damaged Transit_Shelter_Platform_Hazardous',
#   u'responsible_agency': u'Clear Channel - Transit Queue',
#   u'source': u'Voice In',
#   u'status': u'Closed',
#   u'supervisor_district': u'8',
#   u'updated': u'2015-01-26T10:25:35'},
#  {u'address': u'359 DORANTES AVE, SAN FRANCISCO, CA, 94116',
#   u'case_id': u'4427751',
#   u'category': u'Streetlights',
#   u'neighborhood': u'West of Twin Peaks',
#   u'opened': u'2015-01-25T20:49:27',
#   u'point': {u'latitude': u'37.74477217286',
#    u'longitude': u'-122.467367753327',
#    u'needs_recoding': False},
#   u'request_details': u'Light_Burnt_Out on Metal Pole',
#   u'request_type': u'Streetlight - Light_Burnt_Out',
#   u'responsible_agency': u'PG and E - Streetlights Queue',
#   u'source': u'Voice In',
#   u'status': u'Open',
#   u'supervisor_district': u'7',
#   u'updated': u'2015-01-26T14:29:21'},
#  {u'address': u'Intersection of CALIFORNIA ST and MONTGOMERY ST',
#   u'case_id': u'4427727',
#   u'category': u'Litter Receptacles',
#   u'neighborhood': u'Financial District',
#   u'opened': u'2015-01-25T20:29:55',
#   u'point': {u'latitude': u'37.7928512164118',
#    u'longitude': u'-122.402766601343',
#    u'needs_recoding': False},
#   u'request_details': u'N/A',
#   u'request_type': u'Tipped_over',
#   u'responsible_agency': u'DPW Ops Queue',
#   u'source': u'Voice In',
#   u'status': u'Open',
#   u'supervisor_district': u'3',
#   u'updated': u'2015-01-25T20:30:59'},
#  {u'address': u'1500 MASON ST, SAN FRANCISCO, CA, 94133',
#   u'case_id': u'4427724',
#   u'category': u'Street and Sidewalk Cleaning',
#   u'closed': u'2015-01-26T11:07:22',
#   u'neighborhood': u'Russian Hill',
#   u'opened': u'2015-01-25T20:27:46',
#   u'point': {u'latitude': u'37.797440925',
#    u'longitude': u'-122.411773558',
#    u'needs_recoding': False},
#   u'request_details': u'Other Loose Garbage',
#   u'request_type': u'General Cleaning',
#   u'responsible_agency': u'Recology_Abandoned',
#   u'source': u'Open311',
#   u'status': u'Closed',
#   u'supervisor_district': u'3',
#   u'updated': u'2015-01-26T11:07:22'},
#  {u'address': u'1320 14TH AVE, SAN FRANCISCO, CA, 94122',
#   u'case_id': u'4427720',
#   u'category': u'Abandoned Vehicle',
#   u'neighborhood': u'Inner Sunset',
#   u'opened': u'2015-01-25T20:23:35',
#   u'point': {u'latitude': u'37.763023498399',
#    u'longitude': u'-122.471284232873',
#    u'needs_recoding': False},
#   u'request_details': u'gray - Ford - F150 - 05360B1',
#   u'request_type': u'Abandoned Vehicle - PickupTruck',
#   u'responsible_agency': u'DPT Abandoned Vehicles Work Queue',
#   u'source': u'Web Self Service',
#   u'status': u'Open',
#   u'supervisor_district': u'5',
#   u'updated': u'2015-01-26T11:51:07'},
#  {u'address': u'1457 14TH AVE, SAN FRANCISCO, CA, 94122',
#   u'case_id': u'4427717',
#   u'category': u'Abandoned Vehicle',
#   u'neighborhood': u'Inner Sunset',
#   u'opened': u'2015-01-25T20:21:11',
#   u'point': {u'latitude': u'37.760841251428',
#    u'longitude': u'-122.471599443499',
#    u'needs_recoding': False},
#   u'request_details': u'silver - Toyota - Rav4 - 4LBA804',
#   u'request_type': u'Abandoned Vehicle - SUV',
#   u'responsible_agency': u'DPT Abandoned Vehicles Work Queue',
#   u'source': u'Web Self Service',
#   u'status': u'Open',
#   u'supervisor_district': u'7',
#   u'updated': u'2015-01-26T11:50:56'},
#  {u'address': u'1465 14TH AVE, SAN FRANCISCO, CA, 94122',
#   u'case_id': u'4427714',
#   u'category': u'Abandoned Vehicle',
#   u'neighborhood': u'Inner Sunset',
#   u'opened': u'2015-01-25T20:19:24',
#   u'point': {u'latitude': u'37.760718490687',
#    u'longitude': u'-122.47159086025',
#    u'needs_recoding': False},
#   u'request_details': u'black - Acura -  - GAV1589',
#   u'request_type': u'Abandoned Vehicle - Car4door',
#   u'responsible_agency': u'DPT Abandoned Vehicles Work Queue',
#   u'source': u'Web Self Service',
#   u'status': u'Open',
#   u'supervisor_district': u'7',
#   u'updated': u'2015-01-26T11:50:39'},
#  {u'address': u'1145 NOE ST, SAN FRANCISCO, CA, 94114',
#   u'case_id': u'4427709',
#   u'category': u'Sewer Issues',
#   u'closed': u'2015-01-26T19:05:39',
#   u'neighborhood': u'Noe Valley',
#   u'opened': u'2015-01-25T20:16:32',
#   u'point': {u'latitude': u'37.750841941985',
#    u'longitude': u'-122.431626877763',
#    u'needs_recoding': False},
#   u'request_details': u'Outofsewervent4inch',
#   u'request_type': u'Sewage_back_up',
#   u'responsible_agency': u'PUC Sewer Ops',
#   u'source': u'Voice In',
#   u'status': u'Closed',
#   u'supervisor_district': u'8',
#   u'updated': u'2015-01-26T19:05:39'},
#  {u'address': u'2214 JONES ST, SAN FRANCISCO, CA, 94133',
#   u'case_id': u'4427708',
#   u'category': u'Sewer Issues',
#   u'neighborhood': u'Russian Hill',
#   u'opened': u'2015-01-25T20:15:45',
#   u'point': {u'latitude': u'37.801642476558',
#    u'longitude': u'-122.41609611444',
#    u'needs_recoding': False},
#   u'request_details': u'On_property',
#   u'request_type': u'Flooding',
#   u'responsible_agency': u'PUC Sewer Ops',
#   u'source': u'Open311',
#   u'status': u'Open',
#   u'supervisor_district': u'3',
#   u'updated': u'2015-01-25T20:37:20'},
#  {u'address': u'3056 GOUGH ST, SAN FRANCISCO, CA, 94123',
#   u'case_id': u'4427705',
#   u'category': u'Streetlights',
#   u'neighborhood': u'Marina',
#   u'opened': u'2015-01-25T20:11:57',
#   u'point': {u'latitude': u'37.801449044473',
#    u'longitude': u'-122.427868445141',
#    u'needs_recoding': False},
#   u'request_details': u'Light_Burnt_Out on Metal Pole',
#   u'request_type': u'Streetlight - Light_Burnt_Out',
#   u'responsible_agency': u'PUC Streetlights Queue',
#   u'source': u'Open311',
#   u'status': u'Open',
#   u'supervisor_district': u'2',
#   u'updated': u'2015-01-26T16:01:18'},
#  {u'address': u'1262 PAGE ST, SAN FRANCISCO, CA, 94117',
#   u'case_id': u'4427701',
#   u'category': u'Sidewalk or Curb',
#   u'media_url': {u'url': u'http://mobile311.sfgov.org/media/san_francisco/report/photos/54c5bd05df865a0667cd67d6/report.jpg'},
#   u'neighborhood': u'Haight Ashbury',
#   u'opened': u'2015-01-25T20:05:34',
#   u'point': {u'latitude': u'37.771756694497',
#    u'longitude': u'-122.441600657539',
#    u'needs_recoding': False},
#   u'request_details': u'Collapsed_sidewalk',
#   u'request_type': u'Sidewalk_Defect',
#   u'responsible_agency': u'DPW BSM Queue',
#   u'source': u'Open311',
#   u'status': u'Open',
#   u'supervisor_district': u'5',
#   u'updated': u'2015-01-25T20:05:34'},
#  {u'address': u'95 SEACLIFF AVE, SAN FRANCISCO, CA, 94121',
#   u'case_id': u'4427690',
#   u'category': u'Abandoned Vehicle',
#   u'neighborhood': u'Seacliff',
#   u'opened': u'2015-01-25T19:53:06',
#   u'point': {u'latitude': u'37.788793405211',
#    u'longitude': u'-122.486863131283',
#    u'needs_recoding': False},
#   u'request_details': u'Black - BMW - 745I - 3ZZC142',
#   u'request_type': u'Abandoned Vehicle - Car4door',
#   u'responsible_agency': u'DPT Abandoned Vehicles Work Queue',
#   u'source': u'Voice In',
#   u'status': u'Open',
#   u'supervisor_district': u'2',
#   u'updated': u'2015-01-26T11:50:14'},
#  {u'address': u'1690 PAGE ST, SAN FRANCISCO, CA, 94117',
#   u'case_id': u'4427671',
#   u'category': u'Sidewalk or Curb',
#   u'media_url': {u'url': u'http://mobile311.sfgov.org/media/san_francisco/report/photos/54c5b5a5df865a0667cd67c8/report.jpg'},
#   u'neighborhood': u'Haight Ashbury',
#   u'opened': u'2015-01-25T19:34:06',
#   u'point': {u'latitude': u'37.770858489',
#    u'longitude': u'-122.448633997',
#    u'needs_recoding': False},
#   u'request_details': u'Collapsed_sidewalk',
#   u'request_type': u'Sidewalk_Defect',
#   u'responsible_agency': u'DPW BSM Queue',
#   u'source': u'Open311',
#   u'status': u'Open',
#   u'supervisor_district': u'5',
#   u'updated': u'2015-01-25T19:34:06'},
#  {u'address': u'Intersection of BUSH ST and JONES ST',
#   u'case_id': u'4427659',
#   u'category': u'Litter Receptacles',
#   u'neighborhood': u'Downtown/Civic Center',
#   u'opened': u'2015-01-25T19:25:03',
#   u'point': {u'latitude': u'37.7895294371914',
#    u'longitude': u'-122.413728376001',
#    u'needs_recoding': False},
#   u'request_details': u'N/A',
#   u'request_type': u'Cans_Left_Out_24x7',
#   u'responsible_agency': u'DPW Ops Queue',
#   u'source': u'Open311',
#   u'status': u'Open',
#   u'supervisor_district': u'3',
#   u'updated': u'2015-01-25T19:25:03'},
#  {u'address': u'Intersection of DE HARO ST and DIVISION ST',
#   u'case_id': u'4427655',
#   u'category': u'Street and Sidewalk Cleaning',
#   u'closed': u'2015-01-26T10:44:00',
#   u'neighborhood': u'South of Market',
#   u'opened': u'2015-01-25T19:20:23',
#   u'point': {u'latitude': u'37.7698851171923',
#    u'longitude': u'-122.402073085767',
#    u'needs_recoding': False},
#   u'request_details': u'Other Loose Garbage',
#   u'request_type': u'General Cleaning',
#   u'responsible_agency': u'DPW Ops Queue',
#   u'source': u'Open311',
#   u'status': u'Closed',
#   u'supervisor_district': u'10',
#   u'updated': u'2015-01-26T10:44:00'},
#  {u'address': u'Intersection of 17TH AVE and BALBOA ST',
#   u'case_id': u'4427653',
#   u'category': u'Street and Sidewalk Cleaning',
#   u'closed': u'2015-01-26T21:15:21',
#   u'neighborhood': u'Inner Richmond',
#   u'opened': u'2015-01-25T19:19:01',
#   u'point': {u'latitude': u'37.77669283412',
#    u'longitude': u'-122.475888179623',
#    u'needs_recoding': False},
#   u'request_details': u'Glass',
#   u'request_type': u'Hazardous Materials',
#   u'responsible_agency': u'DPW Ops Queue',
#   u'source': u'Voice In',
#   u'status': u'Closed',
#   u'supervisor_district': u'1',
#   u'updated': u'2015-01-26T21:15:21'},
#  {u'address': u'554 FILLMORE ST, SAN FRANCISCO, CA, 94117',
#   u'case_id': u'4427648',
#   u'category': u'Street and Sidewalk Cleaning',
#   u'media_url': {u'url': u'http://mobile311.sfgov.org/media/san_francisco/report/photos/54c5b12adf865a0667cd67a5/report.jpg'},
#   u'neighborhood': u'Western Addition',
#   u'opened': u'2015-01-25T19:15:01',
#   u'point': {u'latitude': u'37.77471560057',
#    u'longitude': u'-122.430814366572',
#    u'needs_recoding': False},
#   u'request_details': u'Other Loose Garbage',
#   u'request_type': u'General Cleaning',
#   u'responsible_agency': u'DPW Ops Queue',
#   u'source': u'Open311',
#   u'status': u'Open',
#   u'supervisor_district': u'5',
#   u'updated': u'2015-01-26T05:51:11'},
#  {u'address': u'500 FILLMORE ST, SAN FRANCISCO, CA, 94117',
#   u'case_id': u'4427642',
#   u'category': u'Street and Sidewalk Cleaning',
#   u'closed': u'2015-01-26T10:40:54',
#   u'media_url': {u'url': u'http://mobile311.sfgov.org/media/san_francisco/report/photos/54c5b0acdf865a0667cd6799/report.jpg'},
#   u'neighborhood': u'Western Addition',
#   u'opened': u'2015-01-25T19:12:53',
#   u'point': {u'latitude': u'37.774194861181',
#    u'longitude': u'-122.430709615164',
#    u'needs_recoding': False},
#   u'request_details': u'Other Loose Garbage',
#   u'request_type': u'General Cleaning',
#   u'responsible_agency': u'Recology_Abandoned',
#   u'source': u'Open311',
#   u'status': u'Closed',
#   u'supervisor_district': u'5',
#   u'updated': u'2015-01-26T10:40:54'},
#  {u'address': u'181 BUENA VISTA AVE, SAN FRANCISCO, CA, 94117',
#   u'case_id': u'4427641',
#   u'category': u'Streetlights',
#   u'neighborhood': u'Haight Ashbury',
#   u'opened': u'2015-01-25T19:12:17',
#   u'point': {u'latitude': u'37.769283470823',
#    u'longitude': u'-122.438357788735',
#    u'needs_recoding': False},
#   u'request_details': u'Light_Burnt_Out on Unknown Pole',
#   u'request_type': u'Streetlight - Light_Burnt_Out',
#   u'responsible_agency': u'PG and E - Streetlights Queue',
#   u'source': u'Voice In',
#   u'status': u'Open',
#   u'supervisor_district': u'8',
#   u'updated': u'2015-01-25T19:13:20'},
#  {u'address': u'1620 SUNNYDALE AVE, SAN FRANCISCO, CA, 94134',
#   u'case_id': u'4427640',
#   u'category': u'SFHA Requests',
#   u'neighborhood': u'Visitacion Valley',
#   u'opened': u'2015-01-25T19:12:11',
#   u'point': {u'latitude': u'37.712141255837',
#    u'longitude': u'-122.416400746312',
#    u'needs_recoding': False},
#   u'request_details': u'Electricians',
#   u'request_type': u'SFHA Priority - Emergency',
#   u'responsible_agency': u'311 HA SR Queue',
#   u'source': u'Voice In',
#   u'status': u'Open',
#   u'supervisor_district': u'10',
#   u'updated': u'2015-01-25T19:20:38'},
#  {u'address': u'Intersection of REVERE AVE and SILVER AVE',
#   u'case_id': u'4427631',
#   u'category': u'General Requests',
#   u'neighborhood': u'Bayview',
#   u'opened': u'2015-01-25T19:07:47',
#   u'point': {u'latitude': u'37.7364330406396',
#    u'longitude': u'-122.398555944436',
#    u'needs_recoding': False},
#   u'request_details': u'dpw - bsm - request_for_service',
#   u'request_type': u'dpw - bsm - request_for_service',
#   u'responsible_agency': u'DPW Ops Queue',
#   u'source': u'Voice In',
#   u'status': u'Open',
#   u'supervisor_district': u'10',
#   u'updated': u'2015-01-26T11:35:47'},
#  {u'address': u'81 BESSIE ST, SAN FRANCISCO, CA, 94110',
#   u'case_id': u'4427627',
#   u'category': u'Litter Receptacles',
#   u'closed': u'2015-01-26T05:53:37',
#   u'neighborhood': u'Bernal Heights',
#   u'opened': u'2015-01-25T19:06:00',
#   u'point': {u'latitude': u'37.746854951159',
#    u'longitude': u'-122.413796771166',
#    u'needs_recoding': False},
#   u'request_details': u'N/A',
#   u'request_type': u'Cans_Left_Out_24x7',
#   u'responsible_agency': u'DPW Ops Queue',
#   u'source': u'Voice In',
#   u'status': u'Closed',
#   u'supervisor_district': u'9',
#   u'updated': u'2015-01-26T05:53:37'},
#  {u'address': u'515 GRANT AVE, SAN FRANCISCO, CA, 94108',
#   u'case_id': u'4427615',
#   u'category': u'Graffiti Private Property',
#   u'neighborhood': u'Chinatown',
#   u'opened': u'2015-01-25T19:00:00',
#   u'point': {u'latitude': u'37.791643508474',
#    u'longitude': u'-122.405984969352',
#    u'needs_recoding': False},
#   u'request_details': u'Building_commercial - Not_Offensive',
#   u'request_type': u'Not_Offensive Graffiti on Private Property',
#   u'responsible_agency': u'DPW Ops Queue',
#   u'source': u'Voice In',
#   u'status': u'Open',
#   u'supervisor_district': u'3',
#   u'updated': u'2015-01-25T19:00:35'},
#  {u'address': u'Corwin Community Garden, 410 DOUGLASS ST, SAN FRANCISCO, CA, 94114',
#   u'case_id': u'4427612',
#   u'category': u'Rec and Park Requests',
#   u'neighborhood': u'Castro/Upper Market',
#   u'opened': u'2015-01-25T18:56:59',
#   u'point': {u'latitude': u'37.757230117',
#    u'longitude': u'-122.4390231',
#    u'needs_recoding': False},
#   u'request_details': u'Trash_Dumping',
#   u'request_type': u'Park - Neighborhood_Services_Area',
#   u'responsible_agency': u'RPD NSA Queue',
#   u'source': u'Voice In',
#   u'status': u'Open',
#   u'supervisor_district': u'8',
#   u'updated': u'2015-01-25T18:57:39'},
#  {u'address': u'3235 3RD ST, SAN FRANCISCO, CA, 94124',
#   u'case_id': u'4427607',
#   u'category': u'Streetlights',
#   u'closed': u'2015-01-26T14:39:27',
#   u'media_url': {u'url': u'http://mobile311.sfgov.org/media/san_francisco/report/photos/54c5ac79df865a0667cd678e/report.jpg'},
#   u'neighborhood': u'Bayview',
#   u'opened': u'2015-01-25T18:54:59',
#   u'point': {u'latitude': u'37.748022441',
#    u'longitude': u'-122.387157916',
#    u'needs_recoding': False},
#   u'request_details': u'Other on Unknown Pole',
#   u'request_type': u'Streetlight - Other',
#   u'responsible_agency': u'311 Supervisor Queue',
#   u'source': u'Open311',
#   u'status': u'Closed',
#   u'supervisor_district': u'10',
#   u'updated': u'2015-01-26T14:39:27'},
#  {u'address': u'2451 SACRAMENTO ST, Apt 406, SAN FRANCISCO, CA, 94115',
#   u'case_id': u'4427589',
#   u'category': u'SFHA Requests',
#   u'neighborhood': u'Pacific Heights',
#   u'opened': u'2015-01-25T18:43:49',
#   u'point': {u'latitude': u'37.789659279457',
#    u'longitude': u'-122.433285782317',
#    u'needs_recoding': False},
#   u'request_details': u'Carpenters',
#   u'request_type': u'SFHA Priority - Emergency',
#   u'responsible_agency': u'311 HA SR Queue',
#   u'source': u'Voice In',
#   u'status': u'Open',
#   u'supervisor_district': u'2',
#   u'updated': u'2015-01-25T18:46:05'},
#  {u'address': u'262 BLYTHDALE AVE, SAN FRANCISCO, CA, 94134',
#   u'case_id': u'4427579',
#   u'category': u'SFHA Requests',
#   u'neighborhood': u'Visitacion Valley',
#   u'opened': u'2015-01-25T18:39:27',
#   u'point': {u'latitude': u'37.711207920042',
#    u'longitude': u'-122.421536263414',
#    u'needs_recoding': False},
#   u'request_details': u'Plumbers',
#   u'request_type': u'SFHA Priority - Emergency',
#   u'responsible_agency': u'311 HA SR Queue',
#   u'source': u'Voice In',
#   u'status': u'Open',
#   u'supervisor_district': u'10',
#   u'updated': u'2015-01-25T18:43:54'},
#  {u'address': u'240 IVY ST, SAN FRANCISCO, CA, 94102',
#   u'case_id': u'4427568',
#   u'category': u'General Requests',
#   u'closed': u'2015-01-26T13:34:01',
#   u'neighborhood': u'Downtown/Civic Center',
#   u'opened': u'2015-01-25T18:35:05',
#   u'point': {u'latitude': u'37.777558212027',
#    u'longitude': u'-122.422167536893',
#    u'needs_recoding': False},
#   u'request_details': u'dph - environmental_health - request_for_service',
#   u'request_type': u'dph - environmental_health - request_for_service',
#   u'responsible_agency': u'DPH - Environmental Health - G',
#   u'source': u'Voice In',
#   u'status': u'Closed',
#   u'supervisor_district': u'5',
#   u'updated': u'2015-01-26T13:34:01'},
#  {u'address': u'Intersection of 15TH AVE and TARAVAL ST',
#   u'case_id': u'4427566',
#   u'category': u'Street and Sidewalk Cleaning',
#   u'neighborhood': u'Parkside',
#   u'opened': u'2015-01-25T18:32:55',
#   u'point': {u'latitude': u'37.7432399182241',
#    u'longitude': u'-122.471356713522',
#    u'needs_recoding': False},
#   u'request_details': u'Other Loose Garbage',
#   u'request_type': u'General Cleaning',
#   u'responsible_agency': u'DPW Ops Queue',
#   u'source': u'Voice In',
#   u'status': u'Open',
#   u'supervisor_district': u'7',
#   u'updated': u'2015-01-26T05:56:09'},
#  {u'address': u'Intersection of CALIFORNIA ST and POLK ST',
#   u'case_id': u'4427564',
#   u'category': u'Streetlights',
#   u'media_url': {u'url': u'http://mobile311.sfgov.org/media/san_francisco/report/photos/54c5a71fdf865a0667cd6780/report.jpg'},
#   u'neighborhood': u'Nob Hill',
#   u'opened': u'2015-01-25T18:32:11',
#   u'point': {u'latitude': u'37.7905782288294',
#    u'longitude': u'-122.420687211284',
#    u'needs_recoding': False},
#   u'request_details': u'Light_Burnt_Out on Metal Pole',
#   u'request_type': u'Streetlight - Light_Burnt_Out',
#   u'responsible_agency': u'PG and E - Streetlights Queue',
#   u'source': u'Open311',
#   u'status': u'Open',
#   u'supervisor_district': u'3',
#   u'updated': u'2015-01-26T14:30:48'},
#  {u'address': u'Intersection of 15TH AVE and TARAVAL ST',
#   u'case_id': u'4427563',
#   u'category': u'Street and Sidewalk Cleaning',
#   u'closed': u'2015-01-26T14:10:27',
#   u'neighborhood': u'Parkside',
#   u'opened': u'2015-01-25T18:31:49',
#   u'point': {u'latitude': u'37.7432399182241',
#    u'longitude': u'-122.471356713522',
#    u'needs_recoding': False},
#   u'request_details': u'Carts',
#   u'request_type': u'Illegal Encampment',
#   u'responsible_agency': u'Recology_Abandoned',
#   u'source': u'Voice In',
#   u'status': u'Closed',
#   u'supervisor_district': u'7',
#   u'updated': u'2015-01-26T14:10:27'},
#  {u'address': u'242 ARGUELLO BLVD, SAN FRANCISCO, CA, 94118',
#   u'case_id': u'4427560',
#   u'category': u'Sewer Issues',
#   u'closed': u'2015-01-26T16:38:11',
#   u'media_url': {u'url': u'https://311crm-prod.ad.sfgov.org/attachments/viewCaseNoteAttachments.jsp?caseid=4427560'},
#   u'neighborhood': u'Presidio Heights',
#   u'opened': u'2015-01-25T18:30:46',
#   u'point': {u'latitude': u'37.786076929668',
#    u'longitude': u'-122.458969377096',
#    u'needs_recoding': False},
#   u'request_details': u'Sewage_back_up Outofsewervent4inch',
#   u'request_type': u'Sewage_back_up',
#   u'responsible_agency': u'PUC Sewer Ops',
#   u'source': u'Web Self Service',
#   u'status': u'Closed',
#   u'supervisor_district': u'2',
#   u'updated': u'2015-01-26T16:38:11'},
#  {u'address': u'Intersection of RUSSIA AVE and VIENNA ST',
#   u'case_id': u'4427556',
#   u'category': u'General Requests',
#   u'neighborhood': u'Excelsior',
#   u'opened': u'2015-01-25T18:29:32',
#   u'point': {u'latitude': u'37.7189159525472',
#    u'longitude': u'-122.431585003931',
#    u'needs_recoding': False},
#   u'request_details': u'dpw - bses - request_for_service',
#   u'request_type': u'dpw - bses - request_for_service',
#   u'responsible_agency': u'DPW - Bureau of Street Environmental Services - G',
#   u'source': u'Voice In',
#   u'status': u'Open',
#   u'supervisor_district': u'11',
#   u'updated': u'2015-01-25T18:31:06'},
#  {u'address': u'3439 BALBOA ST, SAN FRANCISCO, CA, 94121',
#   u'case_id': u'4427552',
#   u'category': u'Graffiti Private Property',
#   u'closed': u'2015-01-26T07:46:15',
#   u'media_url': {u'url': u'http://mobile311.sfgov.org/media/san_francisco/report/photos/54c5a610df865a0667cd6775/report.jpg'},
#   u'neighborhood': u'Outer Richmond',
#   u'opened': u'2015-01-25T18:27:38',
#   u'point': {u'latitude': u'37.77553326',
#    u'longitude': u'-122.495869493',
#    u'needs_recoding': False},
#   u'request_details': u'Building_commercial - Not_Offensive',
#   u'request_type': u'Not_Offensive Graffiti on Private Property',
#   u'responsible_agency': u'DPW Ops Queue',
#   u'source': u'Open311',
#   u'status': u'Closed',
#   u'supervisor_district': u'1',
#   u'updated': u'2015-01-26T07:46:15'},
#  {u'address': u'Intersection of BRIGHTON AVE and OCEAN AVE',
#   u'case_id': u'4427551',
#   u'category': u'Street and Sidewalk Cleaning',
#   u'closed': u'2015-01-26T21:13:37',
#   u'neighborhood': u'West of Twin Peaks',
#   u'opened': u'2015-01-25T18:27:11',
#   u'point': {u'latitude': u'37.7236724812261',
#    u'longitude': u'-122.455135541602',
#    u'needs_recoding': False},
#   u'request_details': u'Glass',
#   u'request_type': u'Hazardous Materials',
#   u'responsible_agency': u'DPW Ops Queue',
#   u'source': u'Voice In',
#   u'status': u'Closed',
#   u'supervisor_district': u'7',
#   u'updated': u'2015-01-26T21:13:37'},
#  {u'address': u'Intersection of 23RD AVE and BALBOA ST',
#   u'case_id': u'4427550',
#   u'category': u'Street and Sidewalk Cleaning',
#   u'closed': u'2015-01-26T11:54:13',
#   u'media_url': {u'url': u'http://mobile311.sfgov.org/media/san_francisco/report/photos/54c5a5c3df865a0667cd676b/report.jpg'},
#   u'neighborhood': u'Outer Richmond',
#   u'opened': u'2015-01-25T18:26:21',
#   u'point': {u'latitude': u'37.776399736897',
#    u'longitude': u'-122.482318490135',
#    u'needs_recoding': False},
#   u'request_details': u'Other Loose Garbage',
#   u'request_type': u'General Cleaning',
#   u'responsible_agency': u'Recology_Abandoned',
#   u'source': u'Open311',
#   u'status': u'Closed',
#   u'supervisor_district': u'1',
#   u'updated': u'2015-01-26T11:54:13'},
#  {u'address': u'598 VIENNA ST, SAN FRANCISCO, CA, 94112',
#   u'case_id': u'4427548',
#   u'category': u'Street and Sidewalk Cleaning',
#   u'closed': u'2015-01-26T11:53:36',
#   u'neighborhood': u'Excelsior',
#   u'opened': u'2015-01-25T18:25:55',
#   u'point': {u'latitude': u'37.719079975736',
#    u'longitude': u'-122.431622647137',
#    u'needs_recoding': False},
#   u'request_details': u'Furniture',
#   u'request_type': u'Bulky Items',
#   u'responsible_agency': u'Recology_Abandoned',
#   u'source': u'Voice In',
#   u'status': u'Closed',
#   u'supervisor_district': u'11',
#   u'updated': u'2015-01-26T11:53:36'},
#  {u'address': u'Intersection of 30TH AVE and BALBOA ST',
#   u'case_id': u'4427545',
#   u'category': u'Graffiti Public Property',
#   u'closed': u'2015-01-26T05:47:34',
#   u'media_url': {u'url': u'http://mobile311.sfgov.org/media/san_francisco/report/photos/54c5a569df865a0667cd6761/report.jpg'},
#   u'neighborhood': u'Outer Richmond',
#   u'opened': u'2015-01-25T18:24:50',
#   u'point': {u'latitude': u'37.7760575230656',
#    u'longitude': u'-122.489815441474',
#    u'needs_recoding': False},
#   u'request_details': u'Transit_Shelter_Platform - Not_Offensive',
#   u'request_type': u'Not_Offensive Graffiti on Public Property',
#   u'responsible_agency': u'Clear Channel - Transit Queue',
#   u'source': u'Open311',
#   u'status': u'Closed',
#   u'supervisor_district': u'1',
#   u'updated': u'2015-01-26T05:47:34'},
#  {u'address': u'Intersection of 18TH ST and DOLORES ST',
#   u'case_id': u'4427544',
#   u'category': u'Street and Sidewalk Cleaning',
#   u'closed': u'2015-01-25T18:47:33',
#   u'neighborhood': u'Castro/Upper Market',
#   u'opened': u'2015-01-25T18:23:45',
#   u'point': {u'latitude': u'37.7614270873961',
#    u'longitude': u'-122.426076474954',
#    u'needs_recoding': False},
#   u'request_details': u'Overflowing_City_Receptacle_or_Dumpster',
#   u'request_type': u'Overflowing_City_Receptacle_or_Dumpster',
#   u'responsible_agency': u'Recology_Overflowing',
#   u'source': u'Voice In',
#   u'status': u'Closed',
#   u'supervisor_district': u'8',
#   u'updated': u'2015-01-25T18:47:33'},
#  {u'address': u'1489 KIRKWOOD AVE, SAN FRANCISCO, CA, 94124',
#   u'case_id': u'4427541',
#   u'category': u'Street and Sidewalk Cleaning',
#   u'closed': u'2015-01-26T11:50:34',
#   u'media_url': {u'url': u'http://mobile311.sfgov.org/media/san_francisco/report/photos/54c5a502df865a0667cd6757/report.jpg'},
#   u'neighborhood': u'Bayview',
#   u'opened': u'2015-01-25T18:23:08',
#   u'point': {u'latitude': u'37.736980336',
#    u'longitude': u'-122.388088109',
#    u'needs_recoding': False},
#   u'request_details': u'Other Loose Garbage',
#   u'request_type': u'General Cleaning',
#   u'responsible_agency': u'Recology_Abandoned',
#   u'source': u'Open311',
#   u'status': u'Closed',
#   u'supervisor_district': u'10',
#   u'updated': u'2015-01-26T11:50:34'},
#  {u'address': u'6945 GEARY BLVD, SAN FRANCISCO, CA, 94121',
#   u'case_id': u'4427537',
#   u'category': u'Street and Sidewalk Cleaning',
#   u'closed': u'2015-01-26T12:09:18',
#   u'media_url': {u'url': u'http://mobile311.sfgov.org/media/san_francisco/report/photos/54c5a4dfdf865a0667cd674c/report.jpg'},
#   u'neighborhood': u'Outer Richmond',
#   u'opened': u'2015-01-25T18:22:32',
#   u'point': {u'latitude': u'37.779453469491',
#    u'longitude': u'-122.494178207029',
#    u'needs_recoding': False},
#   u'request_details': u'Other Loose Garbage',
#   u'request_type': u'General Cleaning',
#   u'responsible_agency': u'Recology_Abandoned',
#   u'source': u'Open311',
#   u'status': u'Closed',
#   u'supervisor_district': u'1',
#   u'updated': u'2015-01-26T12:09:18'},
#  {u'address': u'Intersection of 35TH AVE and ANZA ST',
#   u'case_id': u'4427535',
#   u'category': u'Streetlights',
#   u'media_url': {u'url': u'http://mobile311.sfgov.org/media/san_francisco/report/photos/54c5a48edf865a0667cd6742/report.jpg'},
#   u'neighborhood': u'Outer Richmond',
#   u'opened': u'2015-01-25T18:21:11',
#   u'point': {u'latitude': u'37.7776768265023',
#    u'longitude': u'-122.495310372818',
#    u'needs_recoding': False},
#   u'request_details': u'Light_Burnt_Out on Wooden Pole',
#   u'request_type': u'Streetlight - Light_Burnt_Out',
#   u'responsible_agency': u'PG and E - Streetlights Queue',
#   u'source': u'Open311',
#   u'status': u'Open',
#   u'supervisor_district': u'1',
#   u'updated': u'2015-01-25T18:21:11'},
#  {u'address': u'Intersection of 17TH ST and VALENCIA ST',
#   u'case_id': u'4427534',
#   u'category': u'Sewer Issues',
#   u'closed': u'2015-01-26T09:56:57',
#   u'neighborhood': u'Mission',
#   u'opened': u'2015-01-25T18:21:09',
#   u'point': {u'latitude': u'37.7632997146361',
#    u'longitude': u'-122.421731692575',
#    u'needs_recoding': False},
#   u'request_details': u'From_side_sewer_vent',
#   u'request_type': u'Odor',
#   u'responsible_agency': u'PUC Sewer Ops',
#   u'source': u'Voice In',
#   u'status': u'Closed',
#   u'supervisor_district': u'8',
#   u'updated': u'2015-01-26T09:56:57'},
#  {u'address': u'363 HEARST AVE, SAN FRANCISCO, CA, 94112',
#   u'case_id': u'4427522',
#   u'category': u'Street and Sidewalk Cleaning',
#   u'closed': u'2015-01-26T10:07:18',
#   u'media_url': {u'url': u'http://mobile311.sfgov.org/media/san_francisco/report/photos/54c5a3b1df865a0667cd6737/report.jpg'},
#   u'neighborhood': u'Outer Mission',
#   u'opened': u'2015-01-25T18:17:30',
#   u'point': {u'latitude': u'37.730647683052',
#    u'longitude': u'-122.445719285553',
#    u'needs_recoding': False},
#   u'request_details': u'Furniture',
#   u'request_type': u'Bulky Items',
#   u'responsible_agency': u'Recology_Abandoned',
#   u'source': u'Open311',
#   u'status': u'Closed',
#   u'supervisor_district': u'7',
#   u'updated': u'2015-01-26T10:07:18'},
#  {u'address': u'251 GEARY ST, SAN FRANCISCO, CA, 94102',
#   u'case_id': u'4427500',
#   u'category': u'Damaged Property',
#   u'closed': u'2015-01-26T15:48:21',
#   u'media_url': {u'url': u'http://mobile311.sfgov.org/media/san_francisco/report/photos/54c5a1f9df865a0667cd672d/report.jpg'},
#   u'neighborhood': u'Downtown/Civic Center',
#   u'opened': u'2015-01-25T18:10:07',
#   u'point': {u'latitude': u'37.787337878308',
#    u'longitude': u'-122.407409069094',
#    u'needs_recoding': False},
#   u'request_details': u'Kiosk_Public_Toilet',
#   u'request_type': u'Damaged Kiosk_Public_Toilet',
#   u'responsible_agency': u'311 Supervisor Queue',
#   u'source': u'Open311',
#   u'status': u'Closed',
#   u'supervisor_district': u'3',
#   u'updated': u'2015-01-26T15:48:21'},
#  {u'address': u'Intersection of 23RD ST and FLORIDA ST',
#   u'case_id': u'4427485',
#   u'category': u'Street and Sidewalk Cleaning',
#   u'closed': u'2015-01-26T10:12:22',
#   u'neighborhood': u'Mission',
#   u'opened': u'2015-01-25T18:03:12',
#   u'point': {u'latitude': u'37.75434070481',
#    u'longitude': u'-122.410219900521',
#    u'needs_recoding': False},
#   u'request_details': u'Furniture',
#   u'request_type': u'Bulky Items',
#   u'responsible_agency': u'Recology_Abandoned',
#   u'source': u'Voice In',
#   u'status': u'Closed',
#   u'supervisor_district': u'9',
#   u'updated': u'2015-01-26T10:12:22'},
#  {u'address': u'751 WEBSTER ST, SAN FRANCISCO, CA, 94117',
#   u'case_id': u'4427478',
#   u'category': u'Street and Sidewalk Cleaning',
#   u'neighborhood': u'Western Addition',
#   u'opened': u'2015-01-25T18:00:57',
#   u'point': {u'latitude': u'37.777654229368',
#    u'longitude': u'-122.430016972195',
#    u'needs_recoding': False},
#   u'request_details': u'Other Loose Garbage',
#   u'request_type': u'General Cleaning',
#   u'responsible_agency': u'DPW Ops Queue',
#   u'source': u'Open311',
#   u'status': u'Open',
#   u'supervisor_district': u'5',
#   u'updated': u'2015-01-26T07:48:41'},
#  {u'address': u'1711 45TH AVE, SAN FRANCISCO, CA, 94122',
#   u'case_id': u'4427476',
#   u'category': u'Graffiti Private Property',
#   u'neighborhood': u'Outer Sunset',
#   u'opened': u'2015-01-25T17:59:39',
#   u'point': {u'latitude': u'37.754593258405',
# ...
#   u'source': u'Integrated Agency',
#   u'status': u'Open',
#   u'supervisor_district': u'6',
#   u'updated': u'2015-01-24T12:12:54'},
#  {u'address': u'970 POST ST, SAN FRANCISCO, CA, 94109',
#   u'case_id': u'4424416',
#   u'category': u'Graffiti Private Property',
#   u'neighborhood': u'Downtown/Civic Center',
#   u'opened': u'2015-01-24T12:12:53',
#   u'point': {u'latitude': u'37.787206946192',
#    u'longitude': u'-122.417809902455',
#    u'needs_recoding': False},
#   u'request_details': u'Building_other - Not_Offensive',
#   u'request_type': u'Not_Offensive Graffiti on Private Property',
#   u'responsible_agency': u'DPW Ops Queue',
#   u'source': u'Integrated Agency',
#   u'status': u'Open',
#   u'supervisor_district': u'3',
#   u'updated': u'2015-01-24T12:12:53'},
#  {u'address': u'Intersection of 47TH AVE and BALBOA ST',
#   u'case_id': u'4424415',
#   u'category': u'Graffiti Public Property',
#   u'neighborhood': u'Outer Richmond',
#   u'opened': u'2015-01-24T12:12:35',
#   u'point': {u'latitude': u'37.7752257417352',
#    u'longitude': u'-122.508024393965',
#    u'needs_recoding': False},
#   u'request_details': u'Signal_box - Offensive',
#   u'request_type': u'Offensive Graffiti on Public Property',
#   u'responsible_agency': u'DPW Ops Queue',
#   u'source': u'Voice In',
#   u'status': u'Open',
#   u'supervisor_district': u'1',
#   u'updated': u'2015-01-26T03:22:21'},
#  {u'address': u'Intersection of 12TH ST and HARRISON ST',
#   u'case_id': u'4424407',
#   u'category': u'Street and Sidewalk Cleaning',
#   u'closed': u'2015-01-26T21:15:47',
#   u'media_url': {u'url': u'http://mobile311.sfgov.org/media/san_francisco/report/photos/54c3fbb5df865a0667cd56e7/photo_20150124_120704.jpg'},
#   u'neighborhood': u'South of Market',
#   u'opened': u'2015-01-24T12:09:55',
#   u'point': {u'latitude': u'37.7700517375169',
#    u'longitude': u'-122.413045907727',
#    u'needs_recoding': False},
#   u'request_details': u'Other Loose Garbage',
#   u'request_type': u'General Cleaning',
#   u'responsible_agency': u'DPW Ops Queue',
#   u'source': u'Open311',
#   u'status': u'Closed',
#   u'supervisor_district': u'6',
#   u'updated': u'2015-01-26T21:15:47'},
#  {u'address': u'430 SOUTH VAN NESS AVE, SAN FRANCISCO, CA, 94103',
#   u'case_id': u'4424393',
#   u'category': u'Graffiti Private Property',
#   u'neighborhood': u'Mission',
#   u'opened': u'2015-01-24T12:04:07',
#   u'point': {u'latitude': u'37.766327402901',
#    u'longitude': u'-122.417756885166',
#    u'needs_recoding': False},
#   u'request_details': u'Building_commercial - Not_Offensive',
#   u'request_type': u'Not_Offensive Graffiti on Private Property',
#   u'responsible_agency': u'DPW Ops Queue',
#   u'source': u'Voice In',
#   u'status': u'Open',
#   u'supervisor_district': u'9',
#   u'updated': u'2015-01-24T12:38:44'},
#  {u'address': u'50 CALIFORNIA ST, SAN FRANCISCO, CA, 94111',
#   u'case_id': u'4424364',
#   u'category': u'Damaged Property',
#   u'neighborhood': u'Financial District',
#   u'opened': u'2015-01-24T11:50:15',
#   u'point': {u'latitude': u'37.793683897292',
#    u'longitude': u'-122.397243779655',
#    u'needs_recoding': False},
#   u'request_details': u'Parking_Meter',
#   u'request_type': u'Damaged Parking_Meter',
#   u'responsible_agency': u'DPT Meter_Bike Queue',
#   u'source': u'Voice In',
#   u'status': u'Open',
#   u'supervisor_district': u'3',
#   u'updated': u'2015-01-24T11:51:27'},
#  {u'address': u'91 NORTHRIDGE RD, SAN FRANCISCO, CA, 94124',
#   u'case_id': u'4424354',
#   u'category': u'SFHA Requests',
#   u'neighborhood': u'Bayview',
#   u'opened': u'2015-01-24T11:48:55',
#   u'point': {u'latitude': u'37.730707820479',
#    u'longitude': u'-122.377187339131',
#    u'needs_recoding': False},
#   u'request_details': u'Glaziers',
#   u'request_type': u'SFHA Priority - Preventive',
#   u'responsible_agency': u'311 HA SR Queue',
#   u'source': u'Voice In',
#   u'status': u'Open',
#   u'supervisor_district': u'10',
#   u'updated': u'2015-01-24T11:54:08'},
#  {u'address': u'4 AQUAVISTA WAY, SAN FRANCISCO, CA, 94131',
#   u'case_id': u'4424345',
#   u'category': u'Abandoned Vehicle',
#   u'neighborhood': u'Twin Peaks',
#   u'opened': u'2015-01-24T11:46:32',
#   u'point': {u'latitude': u'37.751159817227',
#    u'longitude': u'-122.449619151033',
#    u'needs_recoding': False},
#   u'request_details': u'white - Honda - Civic EX - 3HEG711',
#   u'request_type': u'Abandoned Vehicle - Car2door',
#   u'responsible_agency': u'DPT Abandoned Vehicles Work Queue',
#   u'source': u'Voice In',
#   u'status': u'Open',
#   u'supervisor_district': u'7',
#   u'updated': u'2015-01-26T11:09:32'},
#  {u'address': u'262 LISBON ST, SAN FRANCISCO, CA, 94112',
#   u'case_id': u'4424337',
#   u'category': u'Sewer Issues',
#   u'closed': u'2015-01-26T08:36:58',
#   u'neighborhood': u'Excelsior',
#   u'opened': u'2015-01-24T11:44:43',
#   u'point': {u'latitude': u'37.724188270744',
#    u'longitude': u'-122.432109429905',
#    u'needs_recoding': False},
#   u'request_details': u'Outofsewervent4inch',
#   u'request_type': u'Sewage_back_up',
#   u'responsible_agency': u'PUC Sewer Ops',
#   u'source': u'Voice In',
#   u'status': u'Closed',
#   u'supervisor_district': u'11',
#   u'updated': u'2015-01-26T08:36:58'},
#  {u'address': u'91 NORTHRIDGE RD, SAN FRANCISCO, CA, 94124',
#   u'case_id': u'4424336',
#   u'category': u'SFHA Requests',
#   u'neighborhood': u'Bayview',
#   u'opened': u'2015-01-24T11:44:32',
#   u'point': {u'latitude': u'37.730707820479',
#    u'longitude': u'-122.377187339131',
#    u'needs_recoding': False},
#   u'request_details': u'Carpenters',
#   u'request_type': u'SFHA Priority - Emergency',
#   u'responsible_agency': u'311 HA SR Queue',
#   u'source': u'Voice In',
#   u'status': u'Open',
#   u'supervisor_district': u'10',
#   u'updated': u'2015-01-24T11:53:25'},
#  {u'address': u'Intersection of GREAT HWY and SLOAT BLVD',
#   u'case_id': u'4424328',
#   u'category': u'Streetlights',
#   u'neighborhood': u'Parkside',
#   u'opened': u'2015-01-24T11:42:36',
#   u'point': {u'latitude': u'37.7355712092976',
#    u'longitude': u'-122.506135173684',
#    u'needs_recoding': False},
#   u'request_details': u'Light_Burnt_Out on Concrete Pole',
#   u'request_type': u'Streetlight - Light_Burnt_Out',
#   u'responsible_agency': u'PUC Streetlights Queue',
#   u'source': u'Web Self Service',
#   u'status': u'Open',
#   u'supervisor_district': u'4',
#   u'updated': u'2015-01-26T15:55:09'},
#  {u'address': u'2950 16TH ST, SAN FRANCISCO, CA, 94103',
#   u'case_id': u'4424327',
#   u'category': u'Graffiti Public Property',
#   u'neighborhood': u'Mission',
#   u'opened': u'2015-01-24T11:42:27',
#   u'point': {u'latitude': u'37.765164927177',
#    u'longitude': u'-122.41870009706',
#    u'needs_recoding': False},
#   u'request_details': u'Pole - Offensive',
#   u'request_type': u'Offensive Graffiti on Public Property',
#   u'responsible_agency': u'DPW Ops Queue',
#   u'source': u'Voice In',
#   u'status': u'Open',
#   u'supervisor_district': u'9',
#   u'updated': u'2015-01-24T11:43:12'},
#  {u'address': u'Intersection of 7TH ST and HOWARD ST',
#   u'case_id': u'4424326',
#   u'category': u'Damaged Property',
#   u'neighborhood': u'South of Market',
#   u'opened': u'2015-01-24T11:41:24',
#   u'point': {u'latitude': u'37.7779771119847',
#    u'longitude': u'-122.409387091848',
#    u'needs_recoding': False},
#   u'request_details': u'Parking_Meter',
#   u'request_type': u'Damaged Parking_Meter',
#   u'responsible_agency': u'DPT Meter_Bike Queue',
#   u'source': u'Voice In',
#   u'status': u'Open',
#   u'supervisor_district': u'6',
#   u'updated': u'2015-01-24T11:42:10'},
#  {u'address': u'1230 HARRISON ST, SAN FRANCISCO, CA, 94103',
#   u'case_id': u'4424303',
#   u'category': u'Blocked Street or SideWalk',
#   u'media_url': {u'url': u'http://mobile311.sfgov.org/media/san_francisco/report/photos/54c3f3d8df865a0667cd56b6/report.jpg'},
#   u'neighborhood': u'South of Market',
#   u'opened': u'2015-01-24T11:34:56',
#   u'point': {u'latitude': u'37.773694957',
#    u'longitude': u'-122.409676017',
#    u'needs_recoding': False},
#   u'request_details': u'Residential_totter blocking sidewalk',
#   u'request_type': u'Blocked_Sidewalk',
#   u'responsible_agency': u'DPW BSM Queue',
#   u'source': u'Open311',
#   u'status': u'Open',
#   u'supervisor_district': u'6',
#   u'updated': u'2015-01-24T11:34:56'},
#  {u'address': u'3008 25TH ST, SAN FRANCISCO, CA, 94110',
#   u'case_id': u'4424301',
#   u'category': u'Sewer Issues',
#   u'closed': u'2015-01-26T08:37:56',
#   u'neighborhood': u'Mission',
#   u'opened': u'2015-01-24T11:34:46',
#   u'point': {u'latitude': u'37.751257756427',
#    u'longitude': u'-122.410241540198',
#    u'needs_recoding': False},
#   u'request_details': u'Outofsewervent4inch',
#   u'request_type': u'Sewage_back_up',
#   u'responsible_agency': u'PUC Sewer Ops',
#   u'source': u'Voice In',
#   u'status': u'Closed',
#   u'supervisor_district': u'9',
#   u'updated': u'2015-01-26T08:37:56'},
#  {u'address': u'900 FOLSOM ST, SAN FRANCISCO, CA, 94107',
#   u'case_id': u'4424291',
#   u'category': u'Damaged Property',
#   u'neighborhood': u'South of Market',
#   u'opened': u'2015-01-24T11:31:59',
#   u'point': {u'latitude': u'37.779999957134',
#    u'longitude': u'-122.403952084935',
#    u'needs_recoding': False},
#   u'request_details': u'Parking_Meter',
#   u'request_type': u'Damaged Parking_Meter',
#   u'responsible_agency': u'DPT Meter_Bike Queue',
#   u'source': u'Voice In',
#   u'status': u'Open',
#   u'supervisor_district': u'6',
#   u'updated': u'2015-01-24T11:33:19'},
#  {u'address': u'640 TURK ST, SAN FRANCISCO, CA, 94102',
#   u'case_id': u'4424278',
#   u'category': u'Damaged Property',
#   u'neighborhood': u'Downtown/Civic Center',
#   u'opened': u'2015-01-24T11:28:21',
#   u'point': {u'latitude': u'37.782186063917',
#    u'longitude': u'-122.419736065438',
#    u'needs_recoding': False},
#   u'request_details': u'Parking_Meter',
#   u'request_type': u'Damaged Parking_Meter',
#   u'responsible_agency': u'DPT Meter_Bike Queue',
#   u'source': u'Voice In',
#   u'status': u'Open',
#   u'supervisor_district': u'6',
#   u'updated': u'2015-01-24T11:29:44'},
#  {u'address': u'709 5TH AVE, SAN FRANCISCO, CA, 94118',
#   u'case_id': u'4424275',
#   u'category': u'Abandoned Vehicle',
#   u'neighborhood': u'Inner Richmond',
#   u'opened': u'2015-01-24T11:27:28',
#   u'point': {u'latitude': u'37.775116569741',
#    u'longitude': u'-122.462958827302',
#    u'needs_recoding': False},
#   u'request_details': u'White - Toyota  - Prius - 7GNT373',
#   u'request_type': u'Abandoned Vehicle - Car4door',
#   u'responsible_agency': u'DPT Abandoned Vehicles Work Queue',
#   u'source': u'Voice In',
#   u'status': u'Open',
#   u'supervisor_district': u'1',
#   u'updated': u'2015-01-26T11:04:24'},
#  {u'address': u'1618 MCALLISTER ST, SAN FRANCISCO, CA, 94115',
#   u'case_id': u'4424267',
#   u'category': u'Sewer Issues',
#   u'closed': u'2015-01-26T08:33:29',
#   u'neighborhood': u'Western Addition',
#   u'opened': u'2015-01-24T11:26:18',
#   u'point': {u'latitude': u'37.77784348248',
#    u'longitude': u'-122.439081046485',
#    u'needs_recoding': False},
#   u'request_details': u'Outofsewervent4inch',
#   u'request_type': u'Sewage_back_up',
#   u'responsible_agency': u'PUC Sewer Ops',
#   u'source': u'Voice In',
#   u'status': u'Closed',
#   u'supervisor_district': u'5',
#   u'updated': u'2015-01-26T08:33:29'},
#  {u'address': u'2970 MISSION ST, SAN FRANCISCO, CA, 94110',
#   u'case_id': u'4424265',
#   u'category': u'Graffiti Private Property',
#   u'neighborhood': u'Mission',
#   u'opened': u'2015-01-24T11:25:35',
#   u'point': {u'latitude': u'37.749421370286',
#    u'longitude': u'-122.418369595837',
#    u'needs_recoding': False},
#   u'request_details': u'Building_commercial - Offensive',
#   u'request_type': u'Offensive Graffiti on Private Property',
#   u'responsible_agency': u'DPW Ops Queue',
#   u'source': u'Voice In',
#   u'status': u'Open',
#   u'supervisor_district': u'9',
#   u'updated': u'2015-01-24T11:26:57'},
#  {u'address': u'2978 MISSION ST, SAN FRANCISCO, CA, 94110',
#   u'case_id': u'4424263',
#   u'category': u'General Requests',
#   u'closed': u'2015-01-26T14:42:01',
#   u'neighborhood': u'Mission',
#   u'opened': u'2015-01-24T11:22:55',
#   u'point': {u'latitude': u'37.749322824452',
#    u'longitude': u'-122.418509434721',
#    u'needs_recoding': False},
#   u'request_details': u'dph - environmental_health - request_for_service',
#   u'request_type': u'dph - environmental_health - request_for_service',
#   u'responsible_agency': u'DPH - Environmental Health - G',
#   u'source': u'Voice In',
#   u'status': u'Closed',
#   u'supervisor_district': u'9',
#   u'updated': u'2015-01-26T14:42:01'},
#  {u'address': u'400 POST ST, SAN FRANCISCO, CA, 94102',
#   u'case_id': u'4424259',
#   u'category': u'Damaged Property',
#   u'neighborhood': u'Downtown/Civic Center',
#   u'opened': u'2015-01-24T11:21:57',
#   u'point': {u'latitude': u'37.788512417445',
#    u'longitude': u'-122.408812411889',
#    u'needs_recoding': False},
#   u'request_details': u'Parking_Meter',
#   u'request_type': u'Damaged Parking_Meter',
#   u'responsible_agency': u'DPT Meter_Bike Queue',
#   u'source': u'Voice In',
#   u'status': u'Open',
#   u'supervisor_district': u'3',
#   u'updated': u'2015-01-24T11:23:58'},
#  {u'address': u'2978 16TH ST, SAN FRANCISCO, CA, 94103',
#   u'case_id': u'4424239',
#   u'category': u'Graffiti Private Property',
#   u'neighborhood': u'Mission',
#   u'opened': u'2015-01-24T11:18:34',
#   u'point': {u'latitude': u'37.765191648767',
#    u'longitude': u'-122.419169719016',
#    u'needs_recoding': False},
#   u'request_details': u'Building_commercial - Offensive',
#   u'request_type': u'Offensive Graffiti on Private Property',
#   u'responsible_agency': u'DPW Ops Queue',
#   u'source': u'Voice In',
#   u'status': u'Open',
#   u'supervisor_district': u'9',
#   u'updated': u'2015-01-24T11:19:25'},
#  {u'address': u'Intersection of FOLSOM ST and RUSS ST',
#   u'case_id': u'4424237',
#   u'category': u'Graffiti Private Property',
#   u'media_url': {u'url': u'http://mobile311.sfgov.org/media/san_francisco/report/photos/54c3efcfdf865a0667cd568f/report.jpg'},
#   u'neighborhood': u'South of Market',
#   u'opened': u'2015-01-24T11:17:43',
#   u'point': {u'latitude': u'37.7776290478207',
#    u'longitude': u'-122.406724407584',
#    u'needs_recoding': False},
#   u'request_details': u'Building_residential - Offensive',
#   u'request_type': u'Offensive Graffiti on Private Property',
#   u'responsible_agency': u'DPW Ops Queue',
#   u'source': u'Open311',
#   u'status': u'Open',
#   u'supervisor_district': u'6',
#   u'updated': u'2015-01-24T11:17:43'},
#  {u'address': u'Intersection of BROADWAY and ROMOLO ST',
#   u'case_id': u'4424233',
#   u'category': u'Damaged Property',
#   u'media_url': {u'url': u'http://mobile311.sfgov.org/media/san_francisco/report/photos/54c3ef38df865a0667cd5683/photo_20150124_111456.jpg'},
#   u'neighborhood': u'North Beach',
#   u'opened': u'2015-01-24T11:15:11',
#   u'point': {u'latitude': u'37.7979201398115',
#    u'longitude': u'-122.406231536823',
#    u'needs_recoding': False},
#   u'request_details': u'Benches_on_Sidewalk',
#   u'request_type': u'Damaged Benches_on_Sidewalk',
#   u'responsible_agency': u'DPW - Bureau of Street Environmental Services - G',
#   u'source': u'Open311',
#   u'status': u'Open',
#   u'supervisor_district': u'3',
#   u'updated': u'2015-01-26T09:35:54'},
#  {u'address': u'725 JERROLD AVE, SAN FRANCISCO, CA, 94124',
#   u'case_id': u'4424231',
#   u'category': u'SFHA Requests',
#   u'neighborhood': u'Bayview',
#   u'opened': u'2015-01-24T11:14:35',
#   u'point': {u'latitude': u'37.729397935797',
#    u'longitude': u'-122.373076447933',
#    u'needs_recoding': False},
#   u'request_details': u'Plumbers',
#   u'request_type': u'SFHA Priority - Emergency',
#   u'responsible_agency': u'311 HA SR Queue',
#   u'source': u'Voice In',
#   u'status': u'Open',
#   u'supervisor_district': u'10',
#   u'updated': u'2015-01-24T11:18:05'},
#  {u'address': u'3328 22ND ST, SAN FRANCISCO, CA, 94110',
#   u'case_id': u'4424226',
#   u'category': u'General Requests',
#   u'neighborhood': u'Mission',
#   u'opened': u'2015-01-24T11:14:14',
#   u'point': {u'latitude': u'37.755363022109',
#    u'longitude': u'-122.421668869478',
#    u'needs_recoding': False},
#   u'request_details': u'dpw - bses - complaint',
#   u'request_type': u'dpw - bses - complaint',
#   u'responsible_agency': u'DPW - Bureau of Street Environmental Services - G',
#   u'source': u'Voice In',
#   u'status': u'Open',
#   u'supervisor_district': u'8',
#   u'updated': u'2015-01-24T11:54:43'}]

# %%
#YOUR CODE HERE - Display the first element (row) in data
#df = pd.DataFrame(list(db.tweets.find(fields=['retweet_count'])))
#df.sort(['retweet_count'],ascending=0).head(15)
df = pd.DataFrame(data=data)
df[:1]
# Out:
#                                         address  case_id            category  \
# 0  Intersection of GOLDEN GATE AVE and JONES ST  4427994  Litter Receptacles
#
#   closed media_url           neighborhood               opened  \
# 0    NaN       NaN  Downtown/Civic Center  2015-01-26T05:11:59
#
#                                                point request_details  \
# 0  {u'latitude': u'37.7820729735132', u'needs_rec...             N/A
#
#        request_type responsible_agency             source status  \
# 0  Damaged_City_Can      DPW Ops Queue  Integrated Agency   Open
#
#   supervisor_district              updated
# 0                   6  2015-01-26T14:23:54

# %% [markdown]
# #### 2. How many elements are there in the JSON file?

# %%
#number of elements or rows
len(df)
# Out:
# 744

# %% [markdown]
# #### Display the length of the JSON object and display the elements contained in one of the items of the JSON file?

# %%
# number of columns in an element or row
len(df.columns)
# Out:
# 15

# %% [markdown]
# ####3. Use Pandas "Read JSON" functionality to turn the 311 data into a Pandas Dataframe and display the first 20 rows

# %%
# unsorted
df = pd.DataFrame(data=data)
df[:20]
# Out:
#                                           address  case_id  \
# 0    Intersection of GOLDEN GATE AVE and JONES ST  4427994
# 1          Intersection of 32ND AVE and FULTON ST  4427993
# 2   1020 CONNECTICUT ST, SAN FRANCISCO, CA, 94107  4427981
# 3       Intersection of BACHE ST and CRESCENT AVE  4427977
# 4          3830 23RD ST, SAN FRANCISCO, CA, 94114  4427972
# ..                                            ...      ...
# 15   Intersection of OFARRELL ST and VAN NESS AVE  4427858
# 16        2296 28TH AVE, SAN FRANCISCO, CA, 94116  4427850
# 17         Intersection of 48TH AVE and IRVING ST  4427848
# 18         438 BROADWAY, SAN FRANCISCO, CA, 94133  4427838
# 19         450 BROADWAY, SAN FRANCISCO, CA, 94133  4427829
#
#                         category               closed  \
# 0             Litter Receptacles                  NaN
# 1   Street and Sidewalk Cleaning  2015-01-26T12:15:28
# 2                  SFHA Requests                  NaN
# 3   Street and Sidewalk Cleaning  2015-01-26T11:28:55
# 4              Abandoned Vehicle                  NaN
# ..                           ...                  ...
# 15                Street Defects                  NaN
# 16  Street and Sidewalk Cleaning  2015-01-26T09:25:33
# 17  Street and Sidewalk Cleaning  2015-01-26T12:29:09
# 18  Street and Sidewalk Cleaning  2015-01-26T02:30:00
# 19  Street and Sidewalk Cleaning  2015-01-26T02:00:00
#
#                                             media_url           neighborhood  \
# 0                                                 NaN  Downtown/Civic Center
# 1                                                 NaN         Outer Richmond
# 2                                                 NaN           Potrero Hill
# 3                                                 NaN         Bernal Heights
# 4                                                 NaN             Noe Valley
# ..                                                ...                    ...
# 15  {u'url': u'https://311crm-prod.ad.sfgov.org/at...       Western Addition
# 16  {u'url': u'http://mobile311.sfgov.org/media/sa...               Parkside
# 17  {u'url': u'http://mobile311.sfgov.org/media/sa...           Outer Sunset
# 18                                                NaN            North Beach
# 19                                                NaN            North Beach
#
#                  opened                                              point  \
# 0   2015-01-26T05:11:59  {u'latitude': u'37.7820729735132', u'needs_rec...
# 1   2015-01-26T04:59:10  {u'latitude': u'37.7722274014997', u'needs_rec...
# 2   2015-01-26T02:10:13  {u'latitude': u'37.753133662641', u'needs_reco...
# 3   2015-01-26T02:03:09  {u'latitude': u'37.7349209780181', u'needs_rec...
# 4   2015-01-26T01:08:08  {u'latitude': u'37.753377557888', u'needs_reco...
# ..                  ...                                                ...
# 15  2015-01-25T22:00:27  {u'latitude': u'37.7847534032066', u'needs_rec...
# 16  2015-01-25T21:50:16  {u'latitude': u'37.744646357352', u'needs_reco...
# 17  2015-01-25T21:49:45  {u'latitude': u'37.7621903064739', u'needs_rec...
# 18  2015-01-25T21:45:01  {u'latitude': u'37.798284752772', u'needs_reco...
# 19  2015-01-25T21:39:31  {u'latitude': u'37.798269699656', u'needs_reco...
#
#               request_details                  request_type  \
# 0                         N/A              Damaged_City_Can
# 1         Other Loose Garbage              General Cleaning
# 2                Electricians        SFHA Priority - Urgent
# 3                Refrigerator                   Bulky Items
# 4   Silver - BMW -  - 6xtv099  Abandoned Vehicle - Car4door
# ..                        ...                           ...
# 15            Pavement_Defect               Pavement_Defect
# 16                  Furniture                   Bulky Items
# 17                  Furniture                   Bulky Items
# 18                Paper Spill              General Cleaning
# 19                Paper Spill              General Cleaning
#
#                    responsible_agency             source  status  \
# 0                       DPW Ops Queue  Integrated Agency    Open
# 1                  Recology_Abandoned           Voice In  Closed
# 2                     311 HA SR Queue           Voice In    Open
# 3                  Recology_Abandoned           Voice In  Closed
# 4   DPT Abandoned Vehicles Work Queue   Web Self Service    Open
# ..                                ...                ...     ...
# 15                     DPW BSSR Queue   Web Self Service    Open
# 16                 Recology_Abandoned            Open311  Closed
# 17                 Recology_Abandoned            Open311  Closed
# 18                      DPW Ops Queue   Web Self Service  Closed
# 19                      DPW Ops Queue   Web Self Service  Closed
#
#    supervisor_district              updated
# 0                    6  2015-01-26T14:23:54
# 1                    1  2015-01-26T12:15:28
# 2                   10  2015-01-26T02:15:39
# 3                    9  2015-01-26T11:28:55
# 4                    8  2015-01-26T11:52:17
# ..                 ...                  ...
# 15                   6  2015-01-26T01:08:17
# 16                   4  2015-01-26T09:25:33
# 17                   4  2015-01-26T12:29:09
# 18                   3  2015-01-26T02:30:00
# 19                   3  2015-01-26T02:00:00
#
# [20 rows x 15 columns]

# %% [markdown]
# ####4. How many missing values do we have?

# %%
# there are 15 cols and 744 rows so rough estimate is half have 1 NaN col and half have 2 col NaN = 744 * 1.5 = 1,116 NaN's
df.count(axis=1, level=None, numeric_only=False)
# Out:
# 0    13
# 1    14
# 2    13
# ...
# 741    14
# 742    13
# 743    13
# Length: 744, dtype: int64

# %% [markdown]
# ####5. Drop the "point" feature from the dataframe - its a dictionary, which is unsupported in a flat database

# %%
DF = df.drop('point', 1)
DF.tail(2)
# Out:
#                                        address  case_id          category  \
# 742  725 JERROLD AVE, SAN FRANCISCO, CA, 94124  4424231     SFHA Requests
# 743     3328 22ND ST, SAN FRANCISCO, CA, 94110  4424226  General Requests
#
#     closed media_url neighborhood               opened  \
# 742    NaN       NaN      Bayview  2015-01-24T11:14:35
# 743    NaN       NaN      Mission  2015-01-24T11:14:14
#
#             request_details               request_type  \
# 742                Plumbers  SFHA Priority - Emergency
# 743  dpw - bses - complaint     dpw - bses - complaint
#
#                                     responsible_agency    source status  \
# 742                                    311 HA SR Queue  Voice In   Open
# 743  DPW - Bureau of Street Environmental Services - G  Voice In   Open
#
#     supervisor_district              updated
# 742                  10  2015-01-24T11:18:05
# 743                   8  2015-01-24T11:54:43

# %% [markdown]
# ####5. Turn the 311 data into a database. You can use the pandas read_sql command (example [here)]('http://bit.ly/1EoP81v') or the db package from yHat to do this.
#
# # notes
# # http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.to_sql.html
# # http://stackoverflow.com/questions/14431646/how-to-write-pandas-dataframe-to-sqlite-with-index

# %%
del df['point']
del df['media_url']

# %%
df.head()
# Out:
#                                          address  case_id  \
# 0   Intersection of GOLDEN GATE AVE and JONES ST  4427994
# 1         Intersection of 32ND AVE and FULTON ST  4427993
# 2  1020 CONNECTICUT ST, SAN FRANCISCO, CA, 94107  4427981
# 3      Intersection of BACHE ST and CRESCENT AVE  4427977
# 4         3830 23RD ST, SAN FRANCISCO, CA, 94114  4427972
#
#                        category               closed           neighborhood  \
# 0            Litter Receptacles                  NaN  Downtown/Civic Center
# 1  Street and Sidewalk Cleaning  2015-01-26T12:15:28         Outer Richmond
# 2                 SFHA Requests                  NaN           Potrero Hill
# 3  Street and Sidewalk Cleaning  2015-01-26T11:28:55         Bernal Heights
# 4             Abandoned Vehicle                  NaN             Noe Valley
#
#                 opened            request_details  \
# 0  2015-01-26T05:11:59                        N/A
# 1  2015-01-26T04:59:10        Other Loose Garbage
# 2  2015-01-26T02:10:13               Electricians
# 3  2015-01-26T02:03:09               Refrigerator
# 4  2015-01-26T01:08:08  Silver - BMW -  - 6xtv099
#
#                    request_type                 responsible_agency  \
# 0              Damaged_City_Can                      DPW Ops Queue
# 1              General Cleaning                 Recology_Abandoned
# 2        SFHA Priority - Urgent                    311 HA SR Queue
# 3                   Bulky Items                 Recology_Abandoned
# 4  Abandoned Vehicle - Car4door  DPT Abandoned Vehicles Work Queue
#
#               source  status supervisor_district              updated
# 0  Integrated Agency    Open                   6  2015-01-26T14:23:54
# 1           Voice In  Closed                   1  2015-01-26T12:15:28
# 2           Voice In    Open                  10  2015-01-26T02:15:39
# 3           Voice In  Closed                   9  2015-01-26T11:28:55
# 4   Web Self Service    Open                   8  2015-01-26T11:52:17

# %%
con = sqlite3.connect("sfgov.sqlite")
dfsql = df.to_sql('tab311', con, if_exists='append')

# %% [markdown]
# ###### 6. Display the first 5 rows of the DB

# %%
pd.read_sql("SELECT * FROM tab311 LIMIT 5", con)
# Out:
#    index                                        address  case_id  \
# 0      0   Intersection of GOLDEN GATE AVE and JONES ST  4427994
# 1      1         Intersection of 32ND AVE and FULTON ST  4427993
# 2      2  1020 CONNECTICUT ST, SAN FRANCISCO, CA, 94107  4427981
# 3      3      Intersection of BACHE ST and CRESCENT AVE  4427977
# 4      4         3830 23RD ST, SAN FRANCISCO, CA, 94114  4427972
#
#                        category               closed media_url  \
# 0            Litter Receptacles                 None      None
# 1  Street and Sidewalk Cleaning  2015-01-26T12:15:28      None
# 2                 SFHA Requests                 None      None
# 3  Street and Sidewalk Cleaning  2015-01-26T11:28:55      None
# 4             Abandoned Vehicle                 None      None
#
#             neighborhood               opened point  \
# 0  Downtown/Civic Center  2015-01-26T05:11:59  None
# 1         Outer Richmond  2015-01-26T04:59:10  None
# 2           Potrero Hill  2015-01-26T02:10:13  None
# 3         Bernal Heights  2015-01-26T02:03:09  None
# 4             Noe Valley  2015-01-26T01:08:08  None
#
#              request_details                  request_type  \
# 0                        N/A              Damaged_City_Can
# 1        Other Loose Garbage              General Cleaning
# 2               Electricians        SFHA Priority - Urgent
# 3               Refrigerator                   Bulky Items
# 4  Silver - BMW -  - 6xtv099  Abandoned Vehicle - Car4door
#
#                   responsible_agency             source  status  \
# 0                      DPW Ops Queue  Integrated Agency    Open
# 1                 Recology_Abandoned           Voice In  Closed
# 2                    311 HA SR Queue           Voice In    Open
# 3                 Recology_Abandoned           Voice In  Closed
# 4  DPT Abandoned Vehicles Work Queue   Web Self Service    Open
#
#   supervisor_district              updated
# 0                   6  2015-01-26T14:23:54
# 1                   1  2015-01-26T12:15:28
# 2                  10  2015-01-26T02:15:39
# 3                   9  2015-01-26T11:28:55
# 4                   8  2015-01-26T11:52:17

# %% [markdown]
# ####7. Show 10 of the sidewalk cleanings in the Haight Ashbury neighborhood

# %%
#YOUR CODE HERE
#pd.read_sql("SELECT * FROM tab311 WHERE request_type like 'Sidewalk_Cleaning' and neighborhood like 'Haight_Ashbury' LIMIT 10", con)
pd.read_sql("SELECT * FROM tab311 WHERE category = 'Street and Sidewalk Cleaning' AND neighborhood = 'Haight Ashbury' LIMIT 10", con)
# Out:
#    index                                     address  case_id  \
# 0    597    635 ASHBURY ST, SAN FRANCISCO, CA, 94117  4425326
# 1    655  Intersection of DOWNEY ST and FREDERICK ST  4425050
# 2    668      Intersection of CARL ST and STANYAN ST  4424823
# 3    597    635 ASHBURY ST, SAN FRANCISCO, CA, 94117  4425326
# 4    655  Intersection of DOWNEY ST and FREDERICK ST  4425050
# 5    668      Intersection of CARL ST and STANYAN ST  4424823
# 6    597    635 ASHBURY ST, SAN FRANCISCO, CA, 94117  4425326
# 7    655  Intersection of DOWNEY ST and FREDERICK ST  4425050
# 8    668      Intersection of CARL ST and STANYAN ST  4424823
#
#                        category               closed media_url  \
# 0  Street and Sidewalk Cleaning                 None      None
# 1  Street and Sidewalk Cleaning  2015-01-25T10:00:53      None
# 2  Street and Sidewalk Cleaning  2015-01-26T21:14:02      None
# 3  Street and Sidewalk Cleaning                 None      None
# 4  Street and Sidewalk Cleaning  2015-01-25T10:00:53      None
# 5  Street and Sidewalk Cleaning  2015-01-26T21:14:02      None
# 6  Street and Sidewalk Cleaning                 None      None
# 7  Street and Sidewalk Cleaning  2015-01-25T10:00:53      None
# 8  Street and Sidewalk Cleaning  2015-01-26T21:14:02      None
#
#      neighborhood               opened point      request_details  \
# 0  Haight Ashbury  2015-01-24T17:26:22  None  Other Loose Garbage
# 1  Haight Ashbury  2015-01-24T15:50:57  None  Other Loose Garbage
# 2  Haight Ashbury  2015-01-24T14:46:37  None  Other Loose Garbage
# 3  Haight Ashbury  2015-01-24T17:26:22  None  Other Loose Garbage
# 4  Haight Ashbury  2015-01-24T15:50:57  None  Other Loose Garbage
# 5  Haight Ashbury  2015-01-24T14:46:37  None  Other Loose Garbage
# 6  Haight Ashbury  2015-01-24T17:26:22  None  Other Loose Garbage
# 7  Haight Ashbury  2015-01-24T15:50:57  None  Other Loose Garbage
# 8  Haight Ashbury  2015-01-24T14:46:37  None  Other Loose Garbage
#
#        request_type responsible_agency    source  status supervisor_district  \
# 0  General Cleaning      DPW Ops Queue  Voice In    Open                   5
# 1  General Cleaning      DPW Ops Queue  Voice In  Closed                   5
# 2  General Cleaning      DPW Ops Queue  Voice In  Closed                   5
# 3  General Cleaning      DPW Ops Queue  Voice In    Open                   5
# 4  General Cleaning      DPW Ops Queue  Voice In  Closed                   5
# 5  General Cleaning      DPW Ops Queue  Voice In  Closed                   5
# 6  General Cleaning      DPW Ops Queue  Voice In    Open                   5
# 7  General Cleaning      DPW Ops Queue  Voice In  Closed                   5
# 8  General Cleaning      DPW Ops Queue  Voice In  Closed                   5
#
#                updated
# 0  2015-01-25T06:43:37
# 1  2015-01-25T10:00:53
# 2  2015-01-26T21:14:02
# 3  2015-01-25T06:43:37
# 4  2015-01-25T10:00:53
# 5  2015-01-26T21:14:02
# 6  2015-01-25T06:43:37
# 7  2015-01-25T10:00:53
# 8  2015-01-26T21:14:02

# %% [markdown]
# ####8. Which type of complaint was most common?

# %%
DF = pd.read_sql("SELECT * FROM tab311", con)
DF['request_type'].value_counts()
# Out:
# General Cleaning                              432
# Bulky Items                                   189
# Not_Offensive Graffiti on Private Property    168
# ...
# mta - paint_shop - request_for_service    3
# puc - puco - complaint                    3
# Building - Hot_Water_Lack_of_Hot_Water    3
# Length: 86, dtype: int64

# %% [markdown]
# ####9. Are there any neighborhoods where sidewalk cleaning requests aren't the most common?

# %%
pd.read_sql("SELECT * FROM tab311 WHERE category = 'Street and Sidewalk Cleaning' LIMIT 10", con)
# Out:
#    index                                    address  case_id  \
# 0      1     Intersection of 32ND AVE and FULTON ST  4427993
# 1      3  Intersection of BACHE ST and CRESCENT AVE  4427977
# 2      6     34 CHURCH ST, SAN FRANCISCO, CA, 94117  4427947
# 3      9   Intersection of 36TH AVE and QUINTARA ST  4427902
# 4     14  292 DOUGLASS ST, SAN FRANCISCO, CA, 94114  4427864
# 5     16    2296 28TH AVE, SAN FRANCISCO, CA, 94116  4427850
# 6     17     Intersection of 48TH AVE and IRVING ST  4427848
# 7     18     438 BROADWAY, SAN FRANCISCO, CA, 94133  4427838
# 8     19     450 BROADWAY, SAN FRANCISCO, CA, 94133  4427829
# 9     27     Intersection of 17TH ST and PROSPER ST  4427762
#
#                        category               closed media_url  \
# 0  Street and Sidewalk Cleaning  2015-01-26T12:15:28      None
# 1  Street and Sidewalk Cleaning  2015-01-26T11:28:55      None
# 2  Street and Sidewalk Cleaning  2015-01-26T09:02:28      None
# 3  Street and Sidewalk Cleaning  2015-01-26T12:49:45      None
# 4  Street and Sidewalk Cleaning  2015-01-26T02:09:00      None
# 5  Street and Sidewalk Cleaning  2015-01-26T09:25:33      None
# 6  Street and Sidewalk Cleaning  2015-01-26T12:29:09      None
# 7  Street and Sidewalk Cleaning  2015-01-26T02:30:00      None
# 8  Street and Sidewalk Cleaning  2015-01-26T02:00:00      None
# 9  Street and Sidewalk Cleaning  2015-01-26T09:20:50      None
#
#           neighborhood               opened point      request_details  \
# 0       Outer Richmond  2015-01-26T04:59:10  None  Other Loose Garbage
# 1       Bernal Heights  2015-01-26T02:03:09  None         Refrigerator
# 2     Western Addition  2015-01-26T00:07:45  None  Other Loose Garbage
# 3         Outer Sunset  2015-01-25T23:03:48  None            Furniture
# 4  Castro/Upper Market  2015-01-25T22:02:35  None  Other Loose Garbage
# 5             Parkside  2015-01-25T21:50:16  None            Furniture
# 6         Outer Sunset  2015-01-25T21:49:45  None            Furniture
# 7          North Beach  2015-01-25T21:45:01  None          Paper Spill
# 8          North Beach  2015-01-25T21:39:31  None          Paper Spill
# 9  Castro/Upper Market  2015-01-25T20:52:57  None            Furniture
#
#        request_type  responsible_agency            source  status  \
# 0  General Cleaning  Recology_Abandoned          Voice In  Closed
# 1       Bulky Items  Recology_Abandoned          Voice In  Closed
# 2  General Cleaning       DPW Ops Queue           Open311  Closed
# 3       Bulky Items  Recology_Abandoned           Open311  Closed
# 4  General Cleaning       DPW Ops Queue           Open311  Closed
# 5       Bulky Items  Recology_Abandoned           Open311  Closed
# 6       Bulky Items  Recology_Abandoned           Open311  Closed
# 7  General Cleaning       DPW Ops Queue  Web Self Service  Closed
# 8  General Cleaning       DPW Ops Queue  Web Self Service  Closed
# 9       Bulky Items  Recology_Abandoned          Voice In  Closed
#
#   supervisor_district              updated
# 0                   1  2015-01-26T12:15:28
# 1                   9  2015-01-26T11:28:55
# 2                   8  2015-01-26T09:02:28
# 3                   4  2015-01-26T12:49:45
# 4                   8  2015-01-26T02:09:00
# 5                   4  2015-01-26T09:25:33
# 6                   4  2015-01-26T12:29:09
# 7                   3  2015-01-26T02:30:00
# 8                   3  2015-01-26T02:00:00
# 9                   8  2015-01-26T09:20:50

# %%
DF = pd.read_sql("SELECT * FROM tab311", con)
DF['neighborhood'].value_counts()
# Out:
# Mission                  333
# South of Market          249
# Downtown/Civic Center    198
# ...
# Lakeshore              9
# Glen Park              3
# Treasure Island/YBI    3
# Length: 36, dtype: int64

# %% [markdown]
# ####BONUS: Come up with your own query! Challenge your fellow classmates by posting your query on HipChat.

# %%
#YOUR CODE HERE
