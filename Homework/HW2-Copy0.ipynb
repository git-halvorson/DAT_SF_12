# %% [markdown]
# ## Homework 2 (Due - Feb'17th) - practice Supervised (KNN) and Un-Supervised (Clustering):
#
# Follow the steps below to:
#     - Read `wine.csv` in the data folder.
#     - We are going to use this dataset to practice Supervised (KNN) and Un-Supervised (Clustering)
#
# ### Supervised (KNN)
#
#     - Split the data into Train and Test (30%) using random_state of 42 (so that we all get same results)
#     - Using KNN, can you predict the Wine class in test
#     - How Accurate is your prediction
#
# ### Un-Supervised (Clustering)
#     - The First Column contains the Wine Category.  Don't use it in the models below.  We are going to treat it as unsupervized learning and compare the results to the Wine column.
#     - Try `KMeans` where `n_clusters = 3` and compare the clusters to the `Wine` column.
#     - Try `Hierarchical Clustering` and plot dendogram
#     - Compare the results of `KMeans` with that of Wine Column.  Is Clustering identifying the Wine groups correctly?
#
# Note that the Wine group codes will not match between Clustering and Wine Category.  What we are looking for is does all the wines in the cluster fall into the same Wine Category).

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import sklearn.datasets as datasets
from matplotlib.colors import ListedColormap
from sklearn import neighbors, datasets, feature_selection
from sklearn.cross_validation import train_test_split, cross_val_score

from seaborn import plt, color_palette
from sklearn.preprocessing import scale

# %%
wine_data = pd.read_csv('/Users/davidhalvorson/Google Drive/General Assembly/Data Science Class/github/DAT_SF_12/data/wine.csv')
wine_data.head(5)
# Out:
#    Wine  Alcohol  Malic.acid   Ash   Acl   Mg  Phenols  Flavanoids  \
# 0     1    14.23        1.71  2.43  15.6  127     2.80        3.06
# 1     1    13.20        1.78  2.14  11.2  100     2.65        2.76
# 2     1    13.16        2.36  2.67  18.6  101     2.80        3.24
# 3     1    14.37        1.95  2.50  16.8  113     3.85        3.49
# 4     1    13.24        2.59  2.87  21.0  118     2.80        2.69
#
#    Nonflavanoid.phenols  Proanth  Color.int   Hue    OD  Proline
# 0                  0.28     2.29       5.64  1.04  3.92     1065
# 1                  0.26     1.28       4.38  1.05  3.40     1050
# 2                  0.30     2.81       5.68  1.03  3.17     1185
# 3                  0.24     2.18       7.80  0.86  3.45     1480
# 4                  0.39     1.82       4.32  1.04  2.93      735

# %%
wine_data.describe()
# Out:
#              Wine     Alcohol  Malic.acid         Ash         Acl          Mg  \
# count  178.000000  178.000000  178.000000  178.000000  178.000000  178.000000
# mean     1.938202   13.000618    2.336348    2.366517   19.494944   99.741573
# std      0.775035    0.811827    1.117146    0.274344    3.339564   14.282484
# min      1.000000   11.030000    0.740000    1.360000   10.600000   70.000000
# 25%      1.000000   12.362500    1.602500    2.210000   17.200000   88.000000
# 50%      2.000000   13.050000    1.865000    2.360000   19.500000   98.000000
# 75%      3.000000   13.677500    3.082500    2.557500   21.500000  107.000000
# max      3.000000   14.830000    5.800000    3.230000   30.000000  162.000000
#
#           Phenols  Flavanoids  Nonflavanoid.phenols     Proanth   Color.int  \
# count  178.000000  178.000000            178.000000  178.000000  178.000000
# mean     2.295112    2.029270              0.361854    1.590899    5.058090
# ...

# %%
wine_labels = pd.read_csv('/Users/davidhalvorson/Google Drive/General Assembly/Data Science Class/github/DAT_SF_12/data/wine_labels.csv', squeeze=True)

wine_labels
# Out:
# Empty DataFrame
# Columns: [Wine, Alcohol, Malic.acid, Ash, Acl, Mg, Phenols, Flavanoids, Nonflavanoid.phenols, Proanth, Color.int, Hue, OD, Proline]
# Index: []

# %%
#wine_data_train, wine_data_test, wine_labels_train, wine_labels_test = train_test_split(wine_data, wine_labels, test_size=0.3, random_state=42)

# %%
# Note the wine.csv was copied to new file with headers removed to load into NP array. Could have also used "drop"...
# for some strange reason could not load
wine_np = np.loadtxt(open("/Users/davidhalvorson/Google Drive/General Assembly/Data Science Class/github/DAT_SF_12/data/wine_nolab.csv","r"),
#wine_np = np.loadtxt(open("data/wine_nolab.csv","r"),
        delimiter=",", 
        skiprows=0, 
        dtype=np.float64
        )

# load the prediction variable Y (1,2,3 who produced the wine)
y = wine_np[:,0]

# convert to int's
y  = y.astype(np.int64, copy=False)
#y

# Load the features into x
x = wine_np[:,1:]
#x

# %%
n_neighbors = range(1, 51, 2)
# Create the training (and test) set using scikit-learn's train_test_split function
#wineData.data, winData.target = 
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %%
scores = []
for n in n_neighbors:
    clf = neighbors.KNeighborsClassifier(n)
    clf.fit(X_train, y_train)
    scores.append(clf.score(X_test, y_test))
    
plt.figure(figsize=(18,6))
_ = plt.plot(n_neighbors, scores, linewidth=3.0)

# K=2 or 27 with random state of 42

# %%
import seaborn
seaborn.pairplot(wineData)

# %%
# Start testing prediction with cross-val
from sklearn.cross_validation import cross_val_score
clf = neighbors.KNeighborsClassifier(27, weights='uniform')
scores = cross_val_score(clf, x, y, cv=5)
print scores
# Out:
# [ 0.7027027   0.72222222  0.63888889  0.71428571  0.79411765]

# %%
# Um not so great
np.mean(scores)
# Out:
# 0.71444343503167029

# %%
clf = neighbors.KNeighborsClassifier(27, weights='uniform')
clf.fit(scale(x[:, 1:12]), y)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_neighbors=27, p=2, weights='uniform')

# %%
h = .02  # step size in the mesh
# Create color maps
cmap_light = ListedColormap(['#FFAAAA', '#AAFFAA', '#AAAAFF'])
cmap_bold = ListedColormap(['#FF0000', '#00FF00', '#0000FF'])

# %%
#wine_feature_names = np.array([['alcohol'],
#       ['malic.acid'], ['ash'],
#       ['acl']],
#      )


wine_feature_names = (['alcohol',
       'malic.acid', 'ash', 'acl', 'mg', 'phenols', 'flavanoids', 'nonflavanoid.phenols', 'proanth', 'color.int', 'hue', 'od',
       'proline']
      )
wine_feature_names
# Out:
# ['alcohol',
#  'malic.acid',
#  'ash',
#  'acl',
#  'mg',
#  'phenols',
#  'flavanoids',
#  'nonflavanoid.phenols',
#  'proanth',
#  'color.int',
#  'hue',
#  'od',
#  'proline']

# %%
n = np.arange(len(wine_feature_names))

fig = plt.figure(figsize=(19,7))
ax = fig.add_subplot(111)

ax.bar(n, feature_selection.f_classif(x, y)[0])

xtickNames = ax.set_xticklabels(wine_feature_names)
ax.set_xticks(n)
_ = plt.setp(xtickNames, rotation=45, fontsize=12)

# %%
# create only top features: Flavonids, proline

clf = neighbors.KNeighborsClassifier(7, weights='uniform')
clf.fit(scale(x[:, [6,12]]), y)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_neighbors=7, p=2, weights='uniform')

# %%
h = .02  # step size in the mesh
# Create color maps
cmap_light = ListedColormap(['#FFAAAA', '#AAFFAA', '#AAAAFF'])
cmap_bold = ListedColormap(['#FF0000', '#00FF00', '#0000FF'])

# %%
# Plot the decision boundary. For that, we will assign a color to each
# point in the mesh [x_min, m_max]x[y_min, y_max].
# a map where red is one feature of wine, green another feature

#x_min, y_min = wine_data.min()[['Flavanoids', 'Proline']]
#x_max, y_max = wine_data.max()[['Flavanoids', 'Proline']]

# Debug
x_min = wine_data.min()[['Flavanoids']]
#x_min

x_max = wine_data.max()[['Flavanoids']]
#x_max

# this returns empty
#y_min = wine_data.min()[['Proline']]
y_min = wine_data[['Proline']]
y_min

y_max = wine_data.max()[['Proline']]
#y_max

#x_min, y_min = wine_data.min()[[:6, :12]]
#x_max, y_max = wine_data.max()[[:6, :12]]

# %%
xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))

Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-141-1addec97cabd> in <module>()
#       1 xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
#       2
# ----> 3 Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
#
# /Users/davidhalvorson/anaconda/lib/python2.7/site-packages/sklearn/neighbors/classification.pyc in predict(self, X)
#     145         X = atleast2d_or_csr(X)
#     146
# --> 147         neigh_dist, neigh_ind = self.kneighbors(X)
#     148
#     149         classes_ = self.classes_
#
# /Users/davidhalvorson/anaconda/lib/python2.7/site-packages/sklearn/neighbors/base.pyc in kneighbors(self, X, n_neighbors, return_distance)
#     330         elif self._fit_method in ['ball_tree', 'kd_tree']:
#     331             result = self._tree.query(X, n_neighbors,
# ...

# %%
#
# Clustering
#

c = [color_palette()[i] for i in y]
plt.scatter(x[:,0], x[:,1], c=c)

# %%
# distance matrix
from scipy.spatial.distance import pdist, squareform
distx = squareform(pdist(x, metric='euclidean'))
distx
# Out:
# array([[   0.        ,   31.26501239,  122.83115403, ...,  230.24002302,
#          225.21518399,  506.05936766],
#        [  31.26501239,    0.        ,  135.22469301, ...,  216.22123207,
#          211.21353863,  490.23526821],
#        [ 122.83115403,  135.22469301,    0.        , ...,  350.57118792,
#          345.56265177,  625.07017782],
#        ...,
#        [ 230.24002302,  216.22123207,  350.57118792, ...,    0.        ,
#            5.35888981,  276.08601522],
#        [ 225.21518399,  211.21353863,  345.56265177, ...,    5.35888981,
#            0.        ,  281.06899242],
#        [ 506.05936766,  490.23526821,  625.07017782, ...,  276.08601522,
#          281.06899242,    0.        ]])

# %%
# perform clustering and plot the dendrogram
from scipy.cluster.hierarchy import linkage, dendrogram

# sending color threshold pushed the linkages down
# the jumps in the data can vary : 10 to 10,0000
R = dendrogram(linkage(distx, method='single'), color_threshold=10)

plt.xlabel('points')
plt.ylabel('Height')
plt.suptitle('Cluster Dendrogram', fontweight='bold', fontsize=11)

# %%
R = dendrogram(linkage(distx, method='ward'), color_threshold=100)

plt.xlabel('points')
plt.ylabel('Height')
plt.suptitle('Cluster Dendrogram', fontweight='bold', fontsize=14)

# %%
# notice moving to scikit-lean
# unsupervised so no need to Y just x the features
# y_hat is the predicted value of Y
from sklearn.cluster import AgglomerativeClustering

# %%
hierarch = AgglomerativeClustering(n_clusters=4, linkage='ward')

# %%
Y_hat_hier = hierarch.fit(x).labels_

# %%
c_hat = [color_palette()[i] for i in Y_hat_hier]
plt.scatter(x[:,0], x[:,1], c=c_hat);

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(4, random_state=1)
Y_hat_kmeans = kmeans.fit(x).labels_

c_hat = [color_palette()[i] for i in Y_hat_kmeans]

plt.scatter(x[:,0], x[:,1], c=c_hat);

# %%
# access cluster centers on k-means
plt.scatter(x[:,0], x[:,1], c=c_hat, alpha=0.4)
mu = kmeans.cluster_centers_
plt.scatter(mu[:,0], mu[:,1], s=100, c=[color_palette()[i] for i in np.unique(Y_hat_kmeans)])
print mu
# Out:
# [[  1.24750877e+01   2.32526316e+00   2.28000000e+00   2.06368421e+01
#     9.17192982e+01   2.10578947e+00   1.87140351e+00   3.83333333e-01
#     1.46842105e+00   3.95210525e+00   9.60526316e-01   2.54438596e+00
#     4.35578947e+02]
#  [  1.38632000e+01   1.78880000e+00   2.48360000e+00   1.66600000e+01
#     1.04840000e+02   2.94040000e+00   3.14040000e+00   2.98800000e-01
#     2.00080000e+00   6.26320000e+00   1.10680000e+00   3.01840000e+00
#     1.32348000e+03]
#  [  1.28700000e+01   2.69762712e+00   2.37932203e+00   2.02406780e+01
#     9.98305085e+01   2.02762712e+00   1.42728814e+00   4.04237288e-01
#     1.43491525e+00   5.55152542e+00   8.70508475e-01   2.27016949e+00
#     6.59220339e+02]
#  [  1.34356757e+01   2.14729730e+00   2.40027027e+00   1.84621622e+01
#     1.08513514e+02   2.57729730e+00   2.48162162e+00   3.03783784e-01
#     1.75135135e+00   5.16081081e+00   9.90432432e-01   2.98513514e+00
#     9.76702703e+02]]
